# %%
# link & mount to google drive to import data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %% [markdown]
# **Load in data**

# %% [markdown]
# #### Old con dataframe

# %%
# import pre-processed data from google drive and store in dataframe using pandas function
# split the dataset into 6 different datasets, one for each class
# GAN model will generate samples for one class at a time, therefore dataframe needs to be split by class. Will be joined again after all samples have been generated.

d_Botnet = pd.read_csv('/content/drive/My Drive/Colab Notebooks/progettoTesi/Dataset2017/improved/Pre-processed_versions/35/d_Botnet35.csv')
d_Bruteforce = pd.read_csv('/content/drive/My Drive/Colab Notebooks/progettoTesi/Dataset2017/improved/Pre-processed_versions/35/d_BruteForce35.csv')

# %% [markdown]
# **Drop label category from each dataframe**

# %%
#colonna superflua perché tanto ho già diviso per classi... la label di ogni df è uguale obv

dfBotnet = d_Botnet.drop(['L_BENIGN','L_Infiltration_Portscan','L_DDoS','L_DoS','L_BruteForce','L_Botnet'], axis=1)
dfBruteforce = d_Botnet.drop(['L_BENIGN','L_Infiltration_Portscan','L_DDoS','L_DoS','L_BruteForce','L_Botnet'], axis=1)

# %%
df = dfBotnet #dfBruteforce

# %%
pd.options.display.float_format = '{:,.20f}'.format

# %% [markdown]
# ```
# BENIGN                   1594422
# Infiltration_Portscan     230853
# DoS                       171620
# DDoS                       95133
# BruteForce                  7005
# Botnet                       736
# ```

# %% [markdown]
# ## **Define model architecture**
#
# model architecture adapted from https://github.com/ydataai/ydata-synthetic - a model for generating credit card data

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
# Allow matplotlib images to render immediately.
# %matplotlib inline

import seaborn as sns

from tensorflow.keras.layers import Input, Dense, Dropout, LeakyReLU, BatchNormalization
from tensorflow.keras import Model

# %%
from tensorflow import keras
# !pip install keras-tuner --upgrade
import keras_tuner as kt
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.6-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.9/128.9 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.15.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.11.17)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.6 kt-legacy-1.0.5

# %%
# !pip install sdv
from sdv.evaluation.single_table import get_column_plot
from sdv.metadata import SingleTableMetadata
from sdv.evaluation.single_table import evaluate_quality
from sdv.evaluation.single_table import run_diagnostic
# Out:
# Collecting sdv
#   Downloading sdv-1.9.0-py2.py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.0/140.0 kB 2.6 MB/s eta 0:00:00
# Collecting boto3<2,>=1.15.0 (from sdv)
#   Downloading boto3-1.34.17-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 12.3 MB/s eta 0:00:00
# Collecting botocore<2,>=1.18 (from sdv)
#   Downloading botocore-1.34.17-py3-none-any.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 101.5 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle<3.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from sdv) (2.2.1)
# Requirement already satisfied: graphviz<1,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from sdv) (0.20.1)
# Requirement already satisfied: tqdm<5,>=4.15 in /usr/local/lib/python3.10/dist-packages (from sdv) (4.66.1)
# Collecting copulas<0.10,>=0.9.0 (from sdv)
#   Downloading copulas-0.9.2-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 7.8 MB/s eta 0:00:00
# Collecting ctgan<0.9,>=0.8 (from sdv)
#   Downloading ctgan-0.8.0-py2.py3-none-any.whl (27 kB)
# Collecting deepecho<0.6,>=0.5 (from sdv)
#   Downloading deepecho-0.5.0-py2.py3-none-any.whl (29 kB)
# Collecting rdt<2,>=1.9.0 (from sdv)
#   Downloading rdt-1.9.1-py2.py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.9/74.9 kB 9.9 MB/s eta 0:00:00
# Collecting sdmetrics<0.14,>=0.13.0 (from sdv)
#   Downloading sdmetrics-0.13.0-py2.py3-none-any.whl (170 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.7/170.7 kB 22.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1.23.3 in /usr/local/lib/python3.10/dist-packages (from sdv) (1.23.5)
# Requirement already satisfied: pandas>=1.3.4 in /usr/local/lib/python3.10/dist-packages (from sdv) (1.5.3)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2,>=1.15.0->sdv)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3<2,>=1.15.0->sdv)
#   Downloading s3transfer-0.10.0-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 12.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<2,>=1.18->sdv) (2.8.2)
# Requirement already satisfied: urllib3<2.1,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<2,>=1.18->sdv) (2.0.7)
# Requirement already satisfied: matplotlib<4,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from copulas<0.10,>=0.9.0->sdv) (3.7.1)
# Requirement already satisfied: scipy<2,>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from copulas<0.10,>=0.9.0->sdv) (1.11.4)
# Requirement already satisfied: scikit-learn<2,>=1.1.3 in /usr/local/lib/python3.10/dist-packages (from ctgan<0.9,>=0.8->sdv) (1.2.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from ctgan<0.9,>=0.8->sdv) (2.1.0+cu121)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.4->sdv) (2023.3.post1)
# Collecting Faker<20,>=17 (from rdt<2,>=1.9.0->sdv)
#   Downloading Faker-19.13.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 91.4 MB/s eta 0:00:00
# Requirement already satisfied: plotly<6,>=5.10.0 in /usr/local/lib/python3.10/dist-packages (from sdmetrics<0.14,>=0.13.0->sdv) (5.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly<6,>=5.10.0->sdmetrics<0.14,>=0.13.0->sdv) (8.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<2,>=1.18->sdv) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=1.1.3->ctgan<0.9,>=0.8->sdv) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=1.1.3->ctgan<0.9,>=0.8->sdv) (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan<0.9,>=0.8->sdv) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan<0.9,>=0.8->sdv) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan<0.9,>=0.8->sdv) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan<0.9,>=0.8->sdv) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan<0.9,>=0.8->sdv) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan<0.9,>=0.8->sdv) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan<0.9,>=0.8->sdv) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->ctgan<0.9,>=0.8->sdv) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->ctgan<0.9,>=0.8->sdv) (1.3.0)
# Installing collected packages: jmespath, Faker, botocore, s3transfer, rdt, deepecho, copulas, sdmetrics, ctgan, boto3, sdv
# Successfully installed Faker-19.13.0 boto3-1.34.17 botocore-1.34.17 copulas-0.9.2 ctgan-0.8.0 deepecho-0.5.0 jmespath-1.0.1 rdt-1.9.1 s3transfer-0.10.0 sdmetrics-0.13.0 sdv-1.9.0

# %% [markdown]
# Modello GAN

# %%
def plot_history(d1_hist, d2_hist, g_hist, a1_hist, a2_hist):
 # plot loss
 plt.subplot(2, 1, 1)
 plt.plot(d1_hist, label='d-loss-real')
 plt.plot(d2_hist, label='d-loss-fake')
 plt.plot(g_hist, label='g-loss')
 plt.legend()
 # plot discriminator accuracy
 plt.subplot(2, 1, 2)
 plt.plot(a1_hist, label='acc-real')
 plt.plot(a2_hist, label='acc-fake')
 plt.legend()

 plt.show()

# %%
alpha_leakyRelu = 0.01 #@param
momentumBN = 0.8 #@param
dropoutRate = 0.1 #@param

# %%
#classe del modello intero GAN
class GANTuner():

    def __init__(self, gan_args):
        [self.batch_size, self.noise_dim, self.data_dim, layers_dim] = gan_args

        self.hyperparameters = HyperParameters()
        self.hyperparameters.Choice('lr_d', [0.001, 0.0001, 0.00001], default=0.001)
        self.hyperparameters.Choice('lr_g', [0.001, 0.0001, 0.00001], default=0.001)

        self.generator = Generator(self.batch_size).\
            build_model(input_shape=(self.noise_dim,), dim=layers_dim, data_dim=self.data_dim)

        self.discriminator = Discriminator(self.batch_size).\
            build_model(input_shape=(self.data_dim,), dim=layers_dim)

        self.tuner = RandomSearch(
            self.build_hypermodel,
            objective='generator_loss',
            max_trials=5,  # Set this to the desired number of trials
            directory='my_tuning_directory',
            project_name='gan_tuning')

    def build_hypermodel(self, hp):
        lr_d = hp.Choice('lr_d', [0.001, 0.0001, 0.00001], default=0.001)
        lr_g = hp.Choice('lr_g', [0.001, 0.0001, 0.00001], default=0.001)

        # Generator
        input_noise = Input(shape=(self.noise_dim,))
        generated_data = self.generator(input_noise)

        # Discriminator
        input_real_data = Input(shape=(self.data_dim,))
        validity = self.discriminator(input_real_data)

        # Combined model
        self.discriminator.trainable = False
        combined_output = self.discriminator(generated_data)

        # Model
        model = Model(inputs=[input_noise, input_real_data], outputs=[generated_data, validity, combined_output])

        optimizer_discriminator = tf.keras.optimizers.Adam(lr_d, 0.5)
        optimizer_generator = tf.keras.optimizers.Adam(lr_g, 0.5)

        model.compile(
            loss=['binary_crossentropy', 'binary_crossentropy', 'binary_crossentropy'],
            optimizer=[optimizer_generator, optimizer_discriminator],
            metrics=['accuracy']
        )

        return model

    def run_tuner(self, data):
      noise = np.random.normal(size=(self.batch_size, self.noise_dim))  # Example noise batch
      real_data_batch = self.get_data_batch(data, self.batch_size)  # Modify this according to your data shape
      # Ensure that the tuner search gets data batches with correct shapes
      self.tuner.search([noise, real_data_batch], epochs=5, validation_split=0.2)


    def get_data_batch(self, train, batch_size, seed=0):
        start_i = (batch_size * seed) % len(train)
        stop_i = start_i + batch_size
        shuffle_seed = (batch_size * seed) // len(train)
        np.random.seed(shuffle_seed)
        train_ix = np.random.choice(list(train.index), replace=False, size=len(train))  # wasteful to shuffle every time
        train_ix = list(train_ix) + list(train_ix)  # duplicate to cover ranges past the end of the set
        x = train.loc[train_ix[start_i: stop_i]].values
        return np.reshape(x, (batch_size, -1))

    def print_architecture(self):
      print("Generator Architecture:")
      self.generator.summary()
      print("\nDiscriminator Architecture:")
      self.discriminator.summary()
      print("\nCombined Model Architecture:")
      self.combined.summary()
      print("\n====================================================================================\n")


    def train(self, data, train_arguments):
        [cache_prefix, epochs, sample_interval] = train_arguments

        data_cols = data.columns

        # Adversarial ground truths
        valid = np.ones((self.batch_size, 1))
        fake = np.zeros((self.batch_size, 1))

        d1_hist, d2_hist, g_hist, a1_hist, a2_hist = list(), list(), list(), list(), list()

        for epoch in range(epochs):
            # Discriminator
            batch_data = self.get_data_batch(data, self.batch_size)
            noise = tf.random.normal((self.batch_size, self.noise_dim))

            # Generate a batch of new samples
            gen_data = self.generator.predict(noise)

            # Train the discriminator
            d_loss_real, d_acc1 = self.discriminator.train_on_batch(batch_data, valid)
            d_loss_fake, d_acc2 = self.discriminator.train_on_batch(gen_data, fake)
            #d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

            # Generator
            noise = tf.random.normal((self.batch_size, self.noise_dim))
            # Train the generator (to have the discriminator label samples as valid)
            g_loss = self.combined.train_on_batch(noise, valid)

            #Therefore, using the loss values directly is not recommended in GANs.
            #Instead, metrics such as the Inception Score, Frechet Inception Distance (FID score),
            #and perceptual similarity measures (LPIPS) are used for interpreting the results.
            #PERFORMANCE
            d1_hist.append(d_loss_real)
            d2_hist.append(d_loss_fake)
            g_hist.append(g_loss)
            a1_hist.append(d_acc1)
            a2_hist.append(d_acc2)
            # Plot the progress
            print('==>> %d, dRLoss=%.3f, dFLoss=%.3f gLoss=%.3f, accR=%d, accF=%d' % (epoch, d_loss_real, d_loss_fake, g_loss, int(100*d_acc1), int(100*d_acc2)))
        plot_history(d1_hist, d2_hist, g_hist, a1_hist, a2_hist)


#DISCRIMINATORE
class Discriminator():
    def __init__(self,batch_size):
        self.batch_size=batch_size

    def build_model(self, input_shape, dim):
        input = Input(shape=input_shape, batch_size=self.batch_size)
        x = Dense(dim * 4)(input)
        x = LeakyReLU(alpha=alpha_leakyRelu)(x)
        x = Dropout(dropoutRate)(x)
        x = Dense(dim * 2)(x)
        x = LeakyReLU(alpha=alpha_leakyRelu)(x)
        x = Dropout(dropoutRate)(x)
        x = Dense(dim)(x)
        x = LeakyReLU(alpha=alpha_leakyRelu)(x)
        x = Dense(1, activation='sigmoid')(x)
        return Model(inputs=input, outputs=x)

# %%
#GENERATOR INIZIALE


class Generator():
    def __init__(self, batch_size):
        self.batch_size = batch_size

    def build_model(self, input_shape, dim, data_dim):
        input_layer = Input(shape=input_shape, batch_size=self.batch_size)
        x = Dense(dim)(input_layer)
        x = LeakyReLU(alpha=alpha_leakyRelu)(x)
        x = BatchNormalization(momentum=momentumBN)(x)
        x = Dense(dim * 2)(x)
        x = LeakyReLU(alpha=alpha_leakyRelu)(x)
        x = BatchNormalization(momentum=momentumBN)(x)
        x = Dense(dim * 4)(x)
        x = LeakyReLU(alpha=alpha_leakyRelu)(x)
        x = BatchNormalization(momentum=momentumBN)(x)
        output_layer = Dense(data_dim, activation='sigmoid')(x) # Use sigmoid activation in the output layer to constrain values to [0, 1]
        return Model(inputs=input_layer, outputs=output_layer)

# %% [markdown]
# Batch Normalization (BN) and dropout are techniques that serve different purposes:
#
# * Batch Normalization (BN):
# > BN is often used to normalize the activations in a layer, which can help with training stability and speed up convergence. It is particularly useful in deep neural networks.
# In the generator, BN can help with avoiding mode collapse and ensuring that the generator learns a diverse set of samples.
#
#
#
# * Dropout:
# > Dropout is a regularization technique where randomly selected neurons are ignored during training. It helps prevent overfitting by introducing noise and reducing reliance on specific neurons.
# In the discriminator, dropout can help prevent the discriminator from becoming too specialized to the training data and encourage the learning of more robust features.
#
#
# While BN and dropout are commonly used in GANs, they are not mandatory.

# %% [markdown]
# ## Training & Generazione

# %% [markdown]
# **Generating class data**

# %% [markdown]
# ```
# BENIGN                   1594422
# Infiltration_Portscan     230853
# DoS                       171620
# DDoS                       95133
# BruteForce                  7005
# Botnet                       736
# ```

# %% [markdown]
# ```
# Given that your original data has 35 features
# --> you might want to experiment with sizes around 35 or slightly larger <--
# to ensure that the input noise vector captures additional variations while respecting the underlying structure of the data
# ```

# %%
data_columns = df.columns
df[data_columns] = df[data_columns]

#generator parameters
batch_size = 256 #@param
lr_d=0.0001 #@param
lr_g=0.0003 #@param
noise_dim = 16  #@param

data_dim=35 #numeroFeatures
layers_dim=64 #@param


#training parameters
epochs = 8000 #@param
log_step = 100

# %%
generator_parameters = [batch_size, lr_d, lr_g, noise_dim, input_shape, dim]
training_parameters = ['', epochs, log_step]

# %% [markdown]
# #### Keras Tuner

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
gan_args = [batch_size, noise_dim, data_dim, layers_dim]

gan_tuner = GANTuner(gan_args)
gan_tuner.run_tuner(df)
# Out:
# Reloading Tuner from my_tuning_directory/gan_tuning/tuner0.json
#
# Search: Running Trial #3
#
# Value             |Best Value So Far |Hyperparameter
# 0.001             |0.001             |lr_d
# 0.0001            |1e-05             |lr_g
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/base_tuner.py", line 273, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/base_tuner.py", line 238, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/tuner.py", line 314, in run_trial
#     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/tuner.py", line 232, in _build_and_fit_model
#     model = self._try_build(hp)
#   File "/usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/tuner.py", line 164, in _try_build
#     model = self._build_hypermodel(hp)
#   File "/usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/tuner.py", line 155, in _build_hypermodel
#     model = self.hypermodel.build(hp)
#   File "<ipython-input-24-a2fa11951c82>", line 41, in build_hypermodel
#     combined_output = self.combined(input_noise)
# AttributeError: 'GANTuner' object has no attribute 'combined'
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-28-4d7be1b6679f> in <cell line: 4>()
#       2
#       3 gan_tuner = GANTuner(gan_args)
# ----> 4 gan_tuner.run_tuner(df)
#
# <ipython-input-24-a2fa11951c82> in run_tuner(self, data)
#      81       real_data_batch = self.get_data_batch(data, self.batch_size)  # Modify this according to your data shape
#      82       # Ensure that the tuner search gets data batches with correct shapes
# ---> 83       self.tuner.search([noise, real_data_batch], epochs=100, validation_split=0.2)
#      84
#      85     #-------------------------------------------------------
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/base_tuner.py in search(self, *fit_args, **fit_kwargs)
#     232             self.on_trial_begin(trial)
#     233             self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
# --> 234             self.on_trial_end(trial)
#     235         self.on_search_end()
#     236
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/base_tuner.py in on_trial_end(self, trial)
#     336             trial: A `Trial` instance.
#     337         """
# --> 338         self.oracle.end_trial(trial)
#     339         self.save()
#     340
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/oracle.py in wrapped_func(*args, **kwargs)
#     106             LOCKS[oracle].acquire()
#     107             THREADS[oracle] = thread_name
# --> 108         ret_val = func(*args, **kwargs)
#     109         if need_acquire:
#     110             THREADS[oracle] = None
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/oracle.py in end_trial(self, trial)
#     584         if not self._retry(trial):
#     585             self.end_order.append(trial.trial_id)
# --> 586             self._check_consecutive_failures()
#     587
#     588         self._save_trial(trial)
#
# /usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/oracle.py in _check_consecutive_failures(self)
#     541                 consecutive_failures = 0
#     542             if consecutive_failures == self.max_consecutive_failed_trials:
# --> 543                 raise RuntimeError(
#     544                     "Number of consecutive failures exceeded the limit "
#     545                     f"of {self.max_consecutive_failed_trials}.\n"
#
# RuntimeError: Number of consecutive failures exceeded the limit of 3.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/base_tuner.py", line 273, in _try_run_and_update_trial
#     self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/base_tuner.py", line 238, in _run_and_update_trial
#     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/tuner.py", line 314, in run_trial
#     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/tuner.py", line 232, in _build_and_fit_model
#     model = self._try_build(hp)
#   File "/usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/tuner.py", line 164, in _try_build
#     model = self._build_hypermodel(hp)
#   File "/usr/local/lib/python3.10/dist-packages/keras_tuner/src/engine/tuner.py", line 155, in _build_hypermodel
#     model = self.hypermodel.build(hp)
#   File "<ipython-input-24-a2fa11951c82>", line 41, in build_hypermodel
#     combined_output = self.combined(input_noise)
# AttributeError: 'GANTuner' object has no attribute 'combined'

# %% [markdown]
# ## Training

# %%
synthesizer = GAN(generator_parameters)
#synthesizer.print_architecture()

# %%
synthesizer.train(df, training_parameters)
# Out:
# Output streaming troncato alle ultime 5000 righe.
# 8/8 [==============================] - 0s 2ms/step
# ==>> 208, dRLoss=0.562, dFLoss=0.502 gLoss=2.877, accR=96, accF=78
# 8/8 [==============================] - 0s 1ms/step
# ==>> 209, dRLoss=0.564, dFLoss=0.495 gLoss=2.936, accR=93, accF=76
# 8/8 [==============================] - 0s 2ms/step
# ==>> 210, dRLoss=0.564, dFLoss=0.520 gLoss=2.608, accR=95, accF=75
# 8/8 [==============================] - 0s 2ms/step
# ==>> 211, dRLoss=0.557, dFLoss=0.515 gLoss=2.426, accR=95, accF=76
# 8/8 [==============================] - 0s 2ms/step
# ==>> 212, dRLoss=0.569, dFLoss=0.512 gLoss=2.791, accR=94, accF=77
# 8/8 [==============================] - 0s 2ms/step
# ==>> 213, dRLoss=0.573, dFLoss=0.555 gLoss=2.884, accR=91, accF=72
# 8/8 [==============================] - 0s 2ms/step
# ==>> 214, dRLoss=0.562, dFLoss=0.532 gLoss=2.698, accR=94, accF=77
# 8/8 [==============================] - 0s 1ms/step
# ==>> 215, dRLoss=0.562, dFLoss=0.516 gLoss=2.549, accR=93, accF=75
# 8/8 [==============================] - 0s 2ms/step
# ==>> 216, dRLoss=0.570, dFLoss=0.506 gLoss=2.744, accR=92, accF=80
# 8/8 [==============================] - 0s 1ms/step
# ==>> 217, dRLoss=0.560, dFLoss=0.522 gLoss=2.622, accR=93, accF=80
# 8/8 [==============================] - 0s 2ms/step
# ==>> 218, dRLoss=0.565, dFLoss=0.500 gLoss=2.635, accR=93, accF=82
# 8/8 [==============================] - 0s 2ms/step
# ==>> 219, dRLoss=0.561, dFLoss=0.525 gLoss=2.566, accR=93, accF=74
# 8/8 [==============================] - 0s 2ms/step
# ==>> 220, dRLoss=0.557, dFLoss=0.496 gLoss=2.556, accR=94, accF=82
# 8/8 [==============================] - 0s 2ms/step
# ==>> 221, dRLoss=0.551, dFLoss=0.544 gLoss=2.570, accR=95, accF=72
# 8/8 [==============================] - 0s 2ms/step
# ==>> 222, dRLoss=0.566, dFLoss=0.549 gLoss=2.810, accR=93, accF=71
# 8/8 [==============================] - 0s 2ms/step
# ==>> 223, dRLoss=0.561, dFLoss=0.543 gLoss=2.420, accR=94, accF=73
# 8/8 [==============================] - 0s 2ms/step
# ==>> 224, dRLoss=0.554, dFLoss=0.546 gLoss=2.677, accR=95, accF=75
# 8/8 [==============================] - 0s 2ms/step
# ==>> 225, dRLoss=0.557, dFLoss=0.546 gLoss=2.875, accR=94, accF=77
# 8/8 [==============================] - 0s 2ms/step
# ==>> 226, dRLoss=0.566, dFLoss=0.541 gLoss=2.663, accR=94, accF=73
# 8/8 [==============================] - 0s 1ms/step
# ==>> 227, dRLoss=0.555, dFLoss=0.539 gLoss=2.878, accR=95, accF=75
# 8/8 [==============================] - 0s 2ms/step
# ==>> 228, dRLoss=0.558, dFLoss=0.550 gLoss=2.658, accR=93, accF=71
# 8/8 [==============================] - 0s 2ms/step
# ==>> 229, dRLoss=0.555, dFLoss=0.511 gLoss=2.698, accR=94, accF=77
# 8/8 [==============================] - 0s 2ms/step
# ==>> 230, dRLoss=0.558, dFLoss=0.533 gLoss=2.521, accR=91, accF=76
# 8/8 [==============================] - 0s 2ms/step
# ==>> 231, dRLoss=0.560, dFLoss=0.537 gLoss=2.337, accR=92, accF=76
# 8/8 [==============================] - 0s 2ms/step
# ==>> 232, dRLoss=0.562, dFLoss=0.534 gLoss=2.584, accR=94, accF=73
# 8/8 [==============================] - 0s 2ms/step
# ==>> 233, dRLoss=0.555, dFLoss=0.549 gLoss=2.928, accR=93, accF=71
# 8/8 [==============================] - 0s 2ms/step
# ==>> 234, dRLoss=0.549, dFLoss=0.563 gLoss=2.968, accR=94, accF=68
# 8/8 [==============================] - 0s 2ms/step
# ==>> 235, dRLoss=0.548, dFLoss=0.537 gLoss=2.405, accR=94, accF=71
# 8/8 [==============================] - 0s 2ms/step
# ==>> 236, dRLoss=0.542, dFLoss=0.542 gLoss=2.552, accR=95, accF=75
# 8/8 [==============================] - 0s 2ms/step
# ==>> 237, dRLoss=0.556, dFLoss=0.546 gLoss=2.643, accR=92, accF=70
# 8/8 [==============================] - 0s 2ms/step
# ==>> 238, dRLoss=0.551, dFLoss=0.566 gLoss=2.477, accR=93, accF=72
# 8/8 [==============================] - 0s 2ms/step
# ==>> 239, dRLoss=0.555, dFLoss=0.562 gLoss=2.526, accR=92, accF=72
# 8/8 [==============================] - 0s 2ms/step
# ==>> 240, dRLoss=0.552, dFLoss=0.551 gLoss=2.708, accR=95, accF=74
# 8/8 [==============================] - 0s 2ms/step
# ==>> 241, dRLoss=0.550, dFLoss=0.533 gLoss=2.467, accR=95, accF=72
# 8/8 [==============================] - 0s 2ms/step
# ==>> 242, dRLoss=0.549, dFLoss=0.546 gLoss=2.307, accR=94, accF=76
# 8/8 [==============================] - 0s 2ms/step
# ==>> 243, dRLoss=0.555, dFLoss=0.549 gLoss=2.515, accR=94, accF=71
# 8/8 [==============================] - 0s 2ms/step
# ==>> 244, dRLoss=0.551, dFLoss=0.578 gLoss=2.741, accR=92, accF=72
# 8/8 [==============================] - 0s 2ms/step
# ==>> 245, dRLoss=0.549, dFLoss=0.556 gLoss=2.545, accR=93, accF=72
# 8/8 [==============================] - 0s 2ms/step
# ==>> 246, dRLoss=0.550, dFLoss=0.548 gLoss=2.458, accR=94, accF=73
# 8/8 [==============================] - 0s 2ms/step
# ==>> 247, dRLoss=0.547, dFLoss=0.549 gLoss=2.541, accR=92, accF=76
# 8/8 [==============================] - 0s 2ms/step
# ==>> 248, dRLoss=0.554, dFLoss=0.556 gLoss=2.426, accR=93, accF=67
# 8/8 [==============================] - 0s 2ms/step
# ==>> 249, dRLoss=0.556, dFLoss=0.546 gLoss=2.711, accR=92, accF=72
# 8/8 [==============================] - 0s 2ms/step
# ==>> 250, dRLoss=0.546, dFLoss=0.546 gLoss=2.289, accR=93, accF=68
# 8/8 [==============================] - 0s 2ms/step
# ==>> 251, dRLoss=0.543, dFLoss=0.549 gLoss=2.910, accR=95, accF=71
# 8/8 [==============================] - 0s 2ms/step
# ==>> 252, dRLoss=0.543, dFLoss=0.559 gLoss=2.693, accR=95, accF=71
# 8/8 [==============================] - 0s 2ms/step
# ==>> 253, dRLoss=0.543, dFLoss=0.567 gLoss=2.781, accR=92, accF=63
# 8/8 [==============================] - 0s 2ms/step
# ==>> 254, dRLoss=0.542, dFLoss=0.546 gLoss=2.306, accR=93, accF=71
# 8/8 [==============================] - 0s 2ms/step
# ==>> 255, dRLoss=0.537, dFLoss=0.589 gLoss=2.586, accR=94, accF=64
# 8/8 [==============================] - 0s 1ms/step
# ==>> 256, dRLoss=0.545, dFLoss=0.610 gLoss=2.657, accR=94, accF=60
# 8/8 [==============================] - 0s 2ms/step
# ==>> 257, dRLoss=0.551, dFLoss=0.570 gLoss=2.250, accR=92, accF=69
# 8/8 [==============================] - 0s 2ms/step
# ==>> 258, dRLoss=0.549, dFLoss=0.565 gLoss=2.625, accR=91, accF=76
# 8/8 [==============================] - 0s 2ms/step
# ==>> 259, dRLoss=0.548, dFLoss=0.581 gLoss=2.530, accR=93, accF=66
# 8/8 [==============================] - 0s 2ms/step
# ==>> 260, dRLoss=0.541, dFLoss=0.589 gLoss=2.390, accR=94, accF=67
# 8/8 [==============================] - 0s 2ms/step
# ==>> 261, dRLoss=0.548, dFLoss=0.571 gLoss=2.501, accR=93, accF=73
# 8/8 [==============================] - 0s 2ms/step
# ==>> 262, dRLoss=0.552, dFLoss=0.583 gLoss=2.462, accR=92, accF=67
# 8/8 [==============================] - 0s 2ms/step
# ==>> 263, dRLoss=0.554, dFLoss=0.551 gLoss=2.132, accR=94, accF=76
# 8/8 [==============================] - 0s 1ms/step
# ==>> 264, dRLoss=0.547, dFLoss=0.557 gLoss=2.315, accR=91, accF=75
# 8/8 [==============================] - 0s 2ms/step
# ==>> 265, dRLoss=0.552, dFLoss=0.572 gLoss=2.359, accR=95, accF=69
# 8/8 [==============================] - 0s 2ms/step
# ==>> 266, dRLoss=0.546, dFLoss=0.558 gLoss=2.311, accR=94, accF=74
# 8/8 [==============================] - 0s 2ms/step
# ==>> 267, dRLoss=0.549, dFLoss=0.552 gLoss=1.919, accR=94, accF=74
# 8/8 [==============================] - 0s 2ms/step
# ==>> 268, dRLoss=0.544, dFLoss=0.547 gLoss=1.934, accR=95, accF=73
# 8/8 [==============================] - 0s 2ms/step
# ==>> 269, dRLoss=0.546, dFLoss=0.539 gLoss=2.510, accR=94, accF=78
# 8/8 [==============================] - 0s 2ms/step
# ==>> 270, dRLoss=0.540, dFLoss=0.559 gLoss=2.283, accR=94, accF=75
# 8/8 [==============================] - 0s 2ms/step
# ==>> 271, dRLoss=0.540, dFLoss=0.549 gLoss=2.325, accR=93, accF=79
# 8/8 [==============================] - 0s 2ms/step
# ==>> 272, dRLoss=0.545, dFLoss=0.522 gLoss=2.435, accR=94, accF=76
# 8/8 [==============================] - 0s 2ms/step
# ==>> 273, dRLoss=0.552, dFLoss=0.536 gLoss=2.527, accR=92, accF=73
# 8/8 [==============================] - 0s 1ms/step
# ==>> 274, dRLoss=0.535, dFLoss=0.547 gLoss=2.617, accR=94, accF=76
# 8/8 [==============================] - 0s 2ms/step
# ==>> 275, dRLoss=0.536, dFLoss=0.528 gLoss=2.089, accR=94, accF=76
# 8/8 [==============================] - 0s 2ms/step
# ==>> 276, dRLoss=0.539, dFLoss=0.578 gLoss=2.133, accR=94, accF=67
# 8/8 [==============================] - 0s 2ms/step
# ==>> 277, dRLoss=0.533, dFLoss=0.578 gLoss=2.288, accR=92, accF=65
# 8/8 [==============================] - 0s 2ms/step
# ==>> 278, dRLoss=0.544, dFLoss=0.607 gLoss=2.094, accR=92, accF=62
# 8/8 [==============================] - 0s 2ms/step
# ==>> 279, dRLoss=0.540, dFLoss=0.577 gLoss=1.999, accR=95, accF=67
# 8/8 [==============================] - 0s 2ms/step
# ==>> 280, dRLoss=0.538, dFLoss=0.582 gLoss=2.061, accR=93, accF=63
# 8/8 [==============================] - 0s 2ms/step
# ==>> 281, dRLoss=0.545, dFLoss=0.612 gLoss=1.934, accR=92, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 282, dRLoss=0.534, dFLoss=0.638 gLoss=1.978, accR=93, accF=56
# 8/8 [==============================] - 0s 2ms/step
# ==>> 283, dRLoss=0.538, dFLoss=0.633 gLoss=1.934, accR=93, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 284, dRLoss=0.538, dFLoss=0.603 gLoss=1.928, accR=92, accF=61
# 8/8 [==============================] - 0s 2ms/step
# ==>> 285, dRLoss=0.533, dFLoss=0.620 gLoss=2.400, accR=95, accF=59
# 8/8 [==============================] - 0s 2ms/step
# ==>> 286, dRLoss=0.551, dFLoss=0.609 gLoss=2.053, accR=93, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 287, dRLoss=0.552, dFLoss=0.628 gLoss=1.979, accR=93, accF=53
# 8/8 [==============================] - 0s 1ms/step
# ==>> 288, dRLoss=0.544, dFLoss=0.631 gLoss=2.640, accR=92, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 289, dRLoss=0.555, dFLoss=0.613 gLoss=2.231, accR=93, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 290, dRLoss=0.544, dFLoss=0.597 gLoss=2.597, accR=92, accF=63
# 8/8 [==============================] - 0s 2ms/step
# ==>> 291, dRLoss=0.549, dFLoss=0.585 gLoss=2.181, accR=93, accF=65
# 8/8 [==============================] - 0s 2ms/step
# ==>> 292, dRLoss=0.554, dFLoss=0.584 gLoss=2.435, accR=92, accF=64
# 8/8 [==============================] - 0s 2ms/step
# ==>> 293, dRLoss=0.550, dFLoss=0.603 gLoss=2.401, accR=94, accF=64
# 8/8 [==============================] - 0s 2ms/step
# ==>> 294, dRLoss=0.559, dFLoss=0.584 gLoss=2.085, accR=90, accF=64
# 8/8 [==============================] - 0s 2ms/step
# ==>> 295, dRLoss=0.550, dFLoss=0.565 gLoss=2.113, accR=93, accF=67
# 8/8 [==============================] - 0s 2ms/step
# ==>> 296, dRLoss=0.548, dFLoss=0.577 gLoss=2.002, accR=92, accF=64
# 8/8 [==============================] - 0s 2ms/step
# ==>> 297, dRLoss=0.552, dFLoss=0.615 gLoss=2.046, accR=92, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 298, dRLoss=0.543, dFLoss=0.584 gLoss=1.957, accR=93, accF=66
# 8/8 [==============================] - 0s 2ms/step
# ==>> 299, dRLoss=0.552, dFLoss=0.591 gLoss=2.099, accR=92, accF=64
# 8/8 [==============================] - 0s 2ms/step
# ==>> 300, dRLoss=0.553, dFLoss=0.599 gLoss=1.930, accR=94, accF=64
# 8/8 [==============================] - 0s 2ms/step
# ==>> 301, dRLoss=0.544, dFLoss=0.653 gLoss=2.610, accR=92, accF=54
# 8/8 [==============================] - 0s 2ms/step
# ==>> 302, dRLoss=0.553, dFLoss=0.648 gLoss=2.116, accR=92, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 303, dRLoss=0.542, dFLoss=0.597 gLoss=2.112, accR=94, accF=60
# 8/8 [==============================] - 0s 2ms/step
# ==>> 304, dRLoss=0.559, dFLoss=0.606 gLoss=1.969, accR=94, accF=62
# 8/8 [==============================] - 0s 2ms/step
# ==>> 305, dRLoss=0.545, dFLoss=0.617 gLoss=2.216, accR=94, accF=62
# 8/8 [==============================] - 0s 2ms/step
# ==>> 306, dRLoss=0.557, dFLoss=0.610 gLoss=2.233, accR=91, accF=62
# 8/8 [==============================] - 0s 2ms/step
# ==>> 307, dRLoss=0.563, dFLoss=0.565 gLoss=2.381, accR=92, accF=71
# 8/8 [==============================] - 0s 2ms/step
# ==>> 308, dRLoss=0.552, dFLoss=0.604 gLoss=2.476, accR=92, accF=56
# 8/8 [==============================] - 0s 2ms/step
# ==>> 309, dRLoss=0.552, dFLoss=0.599 gLoss=2.285, accR=94, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 310, dRLoss=0.550, dFLoss=0.638 gLoss=1.962, accR=92, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 311, dRLoss=0.554, dFLoss=0.619 gLoss=2.404, accR=91, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 312, dRLoss=0.548, dFLoss=0.650 gLoss=1.734, accR=94, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 313, dRLoss=0.558, dFLoss=0.627 gLoss=2.383, accR=91, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 314, dRLoss=0.544, dFLoss=0.622 gLoss=2.133, accR=93, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 315, dRLoss=0.549, dFLoss=0.622 gLoss=2.060, accR=93, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 316, dRLoss=0.551, dFLoss=0.630 gLoss=2.217, accR=94, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 317, dRLoss=0.563, dFLoss=0.642 gLoss=2.403, accR=92, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 318, dRLoss=0.557, dFLoss=0.577 gLoss=1.935, accR=92, accF=64
# 8/8 [==============================] - 0s 2ms/step
# ==>> 319, dRLoss=0.554, dFLoss=0.593 gLoss=1.788, accR=93, accF=62
# 8/8 [==============================] - 0s 2ms/step
# ==>> 320, dRLoss=0.562, dFLoss=0.600 gLoss=1.742, accR=91, accF=62
# 8/8 [==============================] - 0s 2ms/step
# ==>> 321, dRLoss=0.557, dFLoss=0.591 gLoss=2.145, accR=91, accF=62
# 8/8 [==============================] - 0s 2ms/step
# ==>> 322, dRLoss=0.564, dFLoss=0.603 gLoss=1.908, accR=93, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 323, dRLoss=0.554, dFLoss=0.631 gLoss=1.990, accR=95, accF=61
# 8/8 [==============================] - 0s 2ms/step
# ==>> 324, dRLoss=0.554, dFLoss=0.638 gLoss=2.018, accR=93, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 325, dRLoss=0.558, dFLoss=0.602 gLoss=1.781, accR=91, accF=62
# 8/8 [==============================] - 0s 2ms/step
# ==>> 326, dRLoss=0.554, dFLoss=0.598 gLoss=1.987, accR=93, accF=64
# 8/8 [==============================] - 0s 2ms/step
# ==>> 327, dRLoss=0.558, dFLoss=0.612 gLoss=1.949, accR=91, accF=62
# 8/8 [==============================] - 0s 2ms/step
# ==>> 328, dRLoss=0.558, dFLoss=0.625 gLoss=1.821, accR=93, accF=57
# 8/8 [==============================] - 0s 1ms/step
# ==>> 329, dRLoss=0.565, dFLoss=0.627 gLoss=1.698, accR=91, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 330, dRLoss=0.553, dFLoss=0.610 gLoss=2.255, accR=93, accF=62
# 8/8 [==============================] - 0s 2ms/step
# ==>> 331, dRLoss=0.565, dFLoss=0.597 gLoss=1.982, accR=92, accF=66
# 8/8 [==============================] - 0s 2ms/step
# ==>> 332, dRLoss=0.557, dFLoss=0.577 gLoss=2.152, accR=93, accF=71
# 8/8 [==============================] - 0s 2ms/step
# ==>> 333, dRLoss=0.558, dFLoss=0.605 gLoss=1.886, accR=91, accF=64
# 8/8 [==============================] - 0s 2ms/step
# ==>> 334, dRLoss=0.558, dFLoss=0.626 gLoss=1.956, accR=92, accF=60
# 8/8 [==============================] - 0s 2ms/step
# ==>> 335, dRLoss=0.561, dFLoss=0.636 gLoss=2.127, accR=91, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 336, dRLoss=0.556, dFLoss=0.646 gLoss=1.916, accR=93, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 337, dRLoss=0.560, dFLoss=0.626 gLoss=2.155, accR=92, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 338, dRLoss=0.562, dFLoss=0.629 gLoss=2.553, accR=92, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 339, dRLoss=0.559, dFLoss=0.642 gLoss=1.972, accR=93, accF=53
# 8/8 [==============================] - 0s 1ms/step
# ==>> 340, dRLoss=0.568, dFLoss=0.622 gLoss=1.869, accR=91, accF=60
# 8/8 [==============================] - 0s 2ms/step
# ==>> 341, dRLoss=0.573, dFLoss=0.620 gLoss=1.902, accR=90, accF=63
# 8/8 [==============================] - 0s 1ms/step
# ==>> 342, dRLoss=0.565, dFLoss=0.614 gLoss=2.122, accR=91, accF=56
# 8/8 [==============================] - 0s 1ms/step
# ==>> 343, dRLoss=0.560, dFLoss=0.619 gLoss=1.537, accR=91, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 344, dRLoss=0.565, dFLoss=0.613 gLoss=1.556, accR=91, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 345, dRLoss=0.567, dFLoss=0.629 gLoss=1.758, accR=91, accF=60
# 8/8 [==============================] - 0s 2ms/step
# ==>> 346, dRLoss=0.574, dFLoss=0.619 gLoss=1.777, accR=91, accF=62
# 8/8 [==============================] - 0s 2ms/step
# ==>> 347, dRLoss=0.551, dFLoss=0.631 gLoss=1.914, accR=93, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 348, dRLoss=0.562, dFLoss=0.617 gLoss=1.870, accR=91, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 349, dRLoss=0.560, dFLoss=0.596 gLoss=1.719, accR=92, accF=68
# 8/8 [==============================] - 0s 2ms/step
# ==>> 350, dRLoss=0.572, dFLoss=0.566 gLoss=1.949, accR=93, accF=76
# 8/8 [==============================] - 0s 2ms/step
# ==>> 351, dRLoss=0.563, dFLoss=0.591 gLoss=1.860, accR=91, accF=66
# 8/8 [==============================] - 0s 2ms/step
# ==>> 352, dRLoss=0.564, dFLoss=0.612 gLoss=1.867, accR=92, accF=59
# 8/8 [==============================] - 0s 2ms/step
# ==>> 353, dRLoss=0.564, dFLoss=0.617 gLoss=1.813, accR=90, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 354, dRLoss=0.567, dFLoss=0.645 gLoss=1.742, accR=91, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 355, dRLoss=0.570, dFLoss=0.649 gLoss=1.757, accR=91, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 356, dRLoss=0.573, dFLoss=0.660 gLoss=1.847, accR=90, accF=45
# 8/8 [==============================] - 0s 2ms/step
# ==>> 357, dRLoss=0.555, dFLoss=0.636 gLoss=1.604, accR=92, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 358, dRLoss=0.567, dFLoss=0.637 gLoss=1.596, accR=94, accF=54
# 8/8 [==============================] - 0s 2ms/step
# ==>> 359, dRLoss=0.572, dFLoss=0.626 gLoss=1.613, accR=90, accF=59
# 8/8 [==============================] - 0s 2ms/step
# ==>> 360, dRLoss=0.578, dFLoss=0.589 gLoss=2.140, accR=90, accF=69
# 8/8 [==============================] - 0s 2ms/step
# ==>> 361, dRLoss=0.571, dFLoss=0.628 gLoss=1.700, accR=92, accF=60
# 8/8 [==============================] - 0s 2ms/step
# ==>> 362, dRLoss=0.569, dFLoss=0.611 gLoss=1.625, accR=92, accF=66
# 8/8 [==============================] - 0s 2ms/step
# ==>> 363, dRLoss=0.568, dFLoss=0.616 gLoss=1.641, accR=91, accF=64
# 8/8 [==============================] - 0s 2ms/step
# ==>> 364, dRLoss=0.579, dFLoss=0.599 gLoss=2.037, accR=88, accF=68
# 8/8 [==============================] - 0s 2ms/step
# ==>> 365, dRLoss=0.572, dFLoss=0.610 gLoss=1.790, accR=91, accF=65
# 8/8 [==============================] - 0s 2ms/step
# ==>> 366, dRLoss=0.564, dFLoss=0.626 gLoss=1.438, accR=92, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 367, dRLoss=0.568, dFLoss=0.632 gLoss=1.817, accR=92, accF=59
# 8/8 [==============================] - 0s 2ms/step
# ==>> 368, dRLoss=0.585, dFLoss=0.679 gLoss=1.669, accR=89, accF=44
# 8/8 [==============================] - 0s 2ms/step
# ==>> 369, dRLoss=0.564, dFLoss=0.645 gLoss=1.728, accR=91, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 370, dRLoss=0.574, dFLoss=0.672 gLoss=1.558, accR=90, accF=49
# 8/8 [==============================] - 0s 2ms/step
# ==>> 371, dRLoss=0.574, dFLoss=0.657 gLoss=1.872, accR=91, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 372, dRLoss=0.571, dFLoss=0.635 gLoss=1.843, accR=89, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 373, dRLoss=0.571, dFLoss=0.658 gLoss=1.645, accR=91, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 374, dRLoss=0.582, dFLoss=0.638 gLoss=1.463, accR=89, accF=60
# 8/8 [==============================] - 0s 1ms/step
# ==>> 375, dRLoss=0.585, dFLoss=0.650 gLoss=1.915, accR=89, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 376, dRLoss=0.594, dFLoss=0.646 gLoss=1.798, accR=86, accF=56
# 8/8 [==============================] - 0s 2ms/step
# ==>> 377, dRLoss=0.583, dFLoss=0.632 gLoss=1.770, accR=89, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 378, dRLoss=0.581, dFLoss=0.679 gLoss=1.912, accR=90, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 379, dRLoss=0.586, dFLoss=0.653 gLoss=1.718, accR=88, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 380, dRLoss=0.582, dFLoss=0.649 gLoss=1.888, accR=90, accF=54
# 8/8 [==============================] - 0s 2ms/step
# ==>> 381, dRLoss=0.584, dFLoss=0.656 gLoss=1.769, accR=91, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 382, dRLoss=0.582, dFLoss=0.648 gLoss=1.471, accR=90, accF=54
# 8/8 [==============================] - 0s 2ms/step
# ==>> 383, dRLoss=0.581, dFLoss=0.671 gLoss=1.530, accR=91, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 384, dRLoss=0.587, dFLoss=0.659 gLoss=1.433, accR=90, accF=56
# 8/8 [==============================] - 0s 2ms/step
# ==>> 385, dRLoss=0.585, dFLoss=0.667 gLoss=1.760, accR=89, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 386, dRLoss=0.582, dFLoss=0.675 gLoss=1.851, accR=90, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 387, dRLoss=0.593, dFLoss=0.661 gLoss=1.618, accR=88, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 388, dRLoss=0.584, dFLoss=0.658 gLoss=1.450, accR=89, accF=54
# 8/8 [==============================] - 0s 2ms/step
# ==>> 389, dRLoss=0.587, dFLoss=0.659 gLoss=2.124, accR=89, accF=57
# 8/8 [==============================] - 0s 1ms/step
# ==>> 390, dRLoss=0.592, dFLoss=0.676 gLoss=1.844, accR=91, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 391, dRLoss=0.591, dFLoss=0.681 gLoss=1.411, accR=89, accF=44
# 8/8 [==============================] - 0s 2ms/step
# ==>> 392, dRLoss=0.588, dFLoss=0.648 gLoss=2.066, accR=88, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 393, dRLoss=0.601, dFLoss=0.647 gLoss=1.509, accR=88, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 394, dRLoss=0.591, dFLoss=0.607 gLoss=1.577, accR=87, accF=66
# 8/8 [==============================] - 0s 2ms/step
# ==>> 395, dRLoss=0.602, dFLoss=0.584 gLoss=1.571, accR=87, accF=76
# 8/8 [==============================] - 0s 2ms/step
# ==>> 396, dRLoss=0.594, dFLoss=0.573 gLoss=1.595, accR=88, accF=77
# 8/8 [==============================] - 0s 2ms/step
# ==>> 397, dRLoss=0.591, dFLoss=0.622 gLoss=1.999, accR=90, accF=67
# 8/8 [==============================] - 0s 2ms/step
# ==>> 398, dRLoss=0.599, dFLoss=0.637 gLoss=1.511, accR=85, accF=62
# 8/8 [==============================] - 0s 2ms/step
# ==>> 399, dRLoss=0.592, dFLoss=0.595 gLoss=2.114, accR=88, accF=68
# 8/8 [==============================] - 0s 2ms/step
# ==>> 400, dRLoss=0.600, dFLoss=0.614 gLoss=1.664, accR=87, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 401, dRLoss=0.596, dFLoss=0.663 gLoss=1.516, accR=88, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 402, dRLoss=0.603, dFLoss=0.660 gLoss=1.909, accR=86, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 403, dRLoss=0.595, dFLoss=0.666 gLoss=1.732, accR=88, accF=48
# 8/8 [==============================] - 0s 1ms/step
# ==>> 404, dRLoss=0.603, dFLoss=0.658 gLoss=1.709, accR=85, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 405, dRLoss=0.598, dFLoss=0.649 gLoss=1.338, accR=88, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 406, dRLoss=0.600, dFLoss=0.650 gLoss=1.731, accR=89, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 407, dRLoss=0.604, dFLoss=0.639 gLoss=1.836, accR=87, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 408, dRLoss=0.598, dFLoss=0.639 gLoss=1.687, accR=90, accF=61
# 8/8 [==============================] - 0s 2ms/step
# ==>> 409, dRLoss=0.595, dFLoss=0.637 gLoss=1.868, accR=88, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 410, dRLoss=0.596, dFLoss=0.628 gLoss=1.739, accR=88, accF=62
# 8/8 [==============================] - 0s 2ms/step
# ==>> 411, dRLoss=0.599, dFLoss=0.655 gLoss=1.762, accR=84, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 412, dRLoss=0.591, dFLoss=0.666 gLoss=1.243, accR=90, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 413, dRLoss=0.603, dFLoss=0.650 gLoss=1.681, accR=88, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 414, dRLoss=0.606, dFLoss=0.667 gLoss=1.659, accR=85, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 415, dRLoss=0.599, dFLoss=0.677 gLoss=1.770, accR=88, accF=47
# 8/8 [==============================] - 0s 2ms/step
# ==>> 416, dRLoss=0.607, dFLoss=0.669 gLoss=1.379, accR=83, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 417, dRLoss=0.591, dFLoss=0.670 gLoss=1.599, accR=87, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 418, dRLoss=0.606, dFLoss=0.671 gLoss=1.719, accR=84, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 419, dRLoss=0.607, dFLoss=0.650 gLoss=1.814, accR=85, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 420, dRLoss=0.608, dFLoss=0.680 gLoss=1.792, accR=86, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 421, dRLoss=0.602, dFLoss=0.669 gLoss=1.479, accR=88, accF=49
# 8/8 [==============================] - 0s 2ms/step
# ==>> 422, dRLoss=0.608, dFLoss=0.651 gLoss=1.513, accR=85, accF=54
# 8/8 [==============================] - 0s 2ms/step
# ==>> 423, dRLoss=0.606, dFLoss=0.652 gLoss=1.397, accR=87, accF=56
# 8/8 [==============================] - 0s 2ms/step
# ==>> 424, dRLoss=0.603, dFLoss=0.623 gLoss=1.588, accR=86, accF=67
# 8/8 [==============================] - 0s 2ms/step
# ==>> 425, dRLoss=0.602, dFLoss=0.649 gLoss=1.570, accR=85, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 426, dRLoss=0.601, dFLoss=0.648 gLoss=1.851, accR=84, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 427, dRLoss=0.617, dFLoss=0.663 gLoss=1.515, accR=80, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 428, dRLoss=0.607, dFLoss=0.642 gLoss=1.720, accR=87, accF=64
# 8/8 [==============================] - 0s 1ms/step
# ==>> 429, dRLoss=0.608, dFLoss=0.633 gLoss=1.364, accR=85, accF=64
# 8/8 [==============================] - 0s 2ms/step
# ==>> 430, dRLoss=0.606, dFLoss=0.645 gLoss=1.317, accR=86, accF=62
# 8/8 [==============================] - 0s 2ms/step
# ==>> 431, dRLoss=0.603, dFLoss=0.637 gLoss=1.348, accR=89, accF=62
# 8/8 [==============================] - 0s 2ms/step
# ==>> 432, dRLoss=0.615, dFLoss=0.632 gLoss=1.730, accR=87, accF=63
# 8/8 [==============================] - 0s 2ms/step
# ==>> 433, dRLoss=0.620, dFLoss=0.612 gLoss=2.286, accR=84, accF=69
# 8/8 [==============================] - 0s 2ms/step
# ==>> 434, dRLoss=0.606, dFLoss=0.642 gLoss=1.398, accR=88, accF=65
# 8/8 [==============================] - 0s 2ms/step
# ==>> 435, dRLoss=0.615, dFLoss=0.621 gLoss=1.689, accR=82, accF=65
# 8/8 [==============================] - 0s 2ms/step
# ==>> 436, dRLoss=0.604, dFLoss=0.650 gLoss=1.741, accR=87, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 437, dRLoss=0.620, dFLoss=0.650 gLoss=1.718, accR=83, accF=54
# 8/8 [==============================] - 0s 2ms/step
# ==>> 438, dRLoss=0.609, dFLoss=0.629 gLoss=1.629, accR=82, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 439, dRLoss=0.613, dFLoss=0.646 gLoss=1.357, accR=83, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 440, dRLoss=0.616, dFLoss=0.671 gLoss=1.305, accR=85, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 441, dRLoss=0.631, dFLoss=0.633 gLoss=1.453, accR=83, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 442, dRLoss=0.620, dFLoss=0.656 gLoss=1.707, accR=82, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 443, dRLoss=0.607, dFLoss=0.654 gLoss=1.218, accR=87, accF=59
# 8/8 [==============================] - 0s 2ms/step
# ==>> 444, dRLoss=0.612, dFLoss=0.628 gLoss=1.427, accR=85, accF=64
# 8/8 [==============================] - 0s 2ms/step
# ==>> 445, dRLoss=0.618, dFLoss=0.637 gLoss=1.084, accR=84, accF=59
# 8/8 [==============================] - 0s 1ms/step
# ==>> 446, dRLoss=0.615, dFLoss=0.636 gLoss=1.450, accR=83, accF=60
# 8/8 [==============================] - 0s 2ms/step
# ==>> 447, dRLoss=0.617, dFLoss=0.633 gLoss=1.559, accR=85, accF=64
# 8/8 [==============================] - 0s 2ms/step
# ==>> 448, dRLoss=0.614, dFLoss=0.640 gLoss=1.195, accR=85, accF=63
# 8/8 [==============================] - 0s 2ms/step
# ==>> 449, dRLoss=0.608, dFLoss=0.637 gLoss=1.154, accR=86, accF=62
# 8/8 [==============================] - 0s 2ms/step
# ==>> 450, dRLoss=0.608, dFLoss=0.616 gLoss=2.239, accR=86, accF=66
# 8/8 [==============================] - 0s 2ms/step
# ==>> 451, dRLoss=0.628, dFLoss=0.638 gLoss=1.387, accR=78, accF=64
# 8/8 [==============================] - 0s 2ms/step
# ==>> 452, dRLoss=0.604, dFLoss=0.644 gLoss=1.327, accR=85, accF=56
# 8/8 [==============================] - 0s 2ms/step
# ==>> 453, dRLoss=0.626, dFLoss=0.650 gLoss=1.721, accR=82, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 454, dRLoss=0.622, dFLoss=0.625 gLoss=1.668, accR=80, accF=59
# 8/8 [==============================] - 0s 2ms/step
# ==>> 455, dRLoss=0.617, dFLoss=0.639 gLoss=2.205, accR=82, accF=58
# 8/8 [==============================] - 0s 1ms/step
# ==>> 456, dRLoss=0.609, dFLoss=0.648 gLoss=1.332, accR=85, accF=56
# 8/8 [==============================] - 0s 2ms/step
# ==>> 457, dRLoss=0.619, dFLoss=0.646 gLoss=1.273, accR=83, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 458, dRLoss=0.621, dFLoss=0.657 gLoss=1.619, accR=84, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 459, dRLoss=0.614, dFLoss=0.665 gLoss=1.346, accR=84, accF=49
# 8/8 [==============================] - 0s 2ms/step
# ==>> 460, dRLoss=0.608, dFLoss=0.682 gLoss=1.352, accR=85, accF=45
# 8/8 [==============================] - 0s 2ms/step
# ==>> 461, dRLoss=0.623, dFLoss=0.665 gLoss=1.201, accR=82, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 462, dRLoss=0.612, dFLoss=0.674 gLoss=1.537, accR=85, accF=49
# 8/8 [==============================] - 0s 2ms/step
# ==>> 463, dRLoss=0.624, dFLoss=0.683 gLoss=1.225, accR=83, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 464, dRLoss=0.620, dFLoss=0.645 gLoss=1.397, accR=82, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 465, dRLoss=0.629, dFLoss=0.658 gLoss=1.617, accR=82, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 466, dRLoss=0.628, dFLoss=0.669 gLoss=1.311, accR=82, accF=49
# 8/8 [==============================] - 0s 2ms/step
# ==>> 467, dRLoss=0.625, dFLoss=0.643 gLoss=1.234, accR=81, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 468, dRLoss=0.614, dFLoss=0.640 gLoss=1.398, accR=82, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 469, dRLoss=0.623, dFLoss=0.659 gLoss=1.215, accR=83, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 470, dRLoss=0.624, dFLoss=0.652 gLoss=2.590, accR=82, accF=56
# 8/8 [==============================] - 0s 2ms/step
# ==>> 471, dRLoss=0.624, dFLoss=0.653 gLoss=2.476, accR=81, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 472, dRLoss=0.632, dFLoss=0.625 gLoss=1.273, accR=78, accF=61
# 8/8 [==============================] - 0s 2ms/step
# ==>> 473, dRLoss=0.622, dFLoss=0.660 gLoss=1.415, accR=81, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 474, dRLoss=0.624, dFLoss=0.661 gLoss=1.211, accR=80, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 475, dRLoss=0.622, dFLoss=0.650 gLoss=1.230, accR=82, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 476, dRLoss=0.621, dFLoss=0.645 gLoss=1.233, accR=80, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 477, dRLoss=0.623, dFLoss=0.652 gLoss=1.451, accR=82, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 478, dRLoss=0.635, dFLoss=0.690 gLoss=1.218, accR=80, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 479, dRLoss=0.620, dFLoss=0.668 gLoss=1.706, accR=83, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 480, dRLoss=0.639, dFLoss=0.654 gLoss=1.365, accR=78, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 481, dRLoss=0.623, dFLoss=0.681 gLoss=1.546, accR=80, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 482, dRLoss=0.627, dFLoss=0.663 gLoss=1.263, accR=86, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 483, dRLoss=0.626, dFLoss=0.662 gLoss=1.561, accR=81, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 484, dRLoss=0.634, dFLoss=0.677 gLoss=2.053, accR=81, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 485, dRLoss=0.618, dFLoss=0.667 gLoss=1.062, accR=83, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 486, dRLoss=0.633, dFLoss=0.654 gLoss=1.245, accR=76, accF=54
# 8/8 [==============================] - 0s 2ms/step
# ==>> 487, dRLoss=0.639, dFLoss=0.662 gLoss=1.202, accR=79, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 488, dRLoss=0.620, dFLoss=0.672 gLoss=1.514, accR=81, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 489, dRLoss=0.637, dFLoss=0.668 gLoss=1.298, accR=80, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 490, dRLoss=0.624, dFLoss=0.672 gLoss=1.377, accR=82, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 491, dRLoss=0.635, dFLoss=0.690 gLoss=1.389, accR=75, accF=43
# 8/8 [==============================] - 0s 2ms/step
# ==>> 492, dRLoss=0.637, dFLoss=0.658 gLoss=1.183, accR=79, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 493, dRLoss=0.634, dFLoss=0.654 gLoss=1.786, accR=78, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 494, dRLoss=0.626, dFLoss=0.667 gLoss=1.228, accR=82, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 495, dRLoss=0.630, dFLoss=0.682 gLoss=1.418, accR=83, accF=47
# 8/8 [==============================] - 0s 2ms/step
# ==>> 496, dRLoss=0.622, dFLoss=0.672 gLoss=1.327, accR=82, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 497, dRLoss=0.621, dFLoss=0.691 gLoss=1.679, accR=81, accF=42
# 8/8 [==============================] - 0s 2ms/step
# ==>> 498, dRLoss=0.628, dFLoss=0.689 gLoss=1.253, accR=80, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 499, dRLoss=0.643, dFLoss=0.705 gLoss=1.624, accR=78, accF=43
# 8/8 [==============================] - 0s 2ms/step
# ==>> 500, dRLoss=0.637, dFLoss=0.651 gLoss=1.429, accR=79, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 501, dRLoss=0.632, dFLoss=0.668 gLoss=1.001, accR=79, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 502, dRLoss=0.643, dFLoss=0.664 gLoss=1.378, accR=76, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 503, dRLoss=0.620, dFLoss=0.661 gLoss=1.211, accR=80, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 504, dRLoss=0.642, dFLoss=0.671 gLoss=1.386, accR=78, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 505, dRLoss=0.638, dFLoss=0.640 gLoss=1.274, accR=73, accF=60
# 8/8 [==============================] - 0s 2ms/step
# ==>> 506, dRLoss=0.646, dFLoss=0.644 gLoss=1.236, accR=74, accF=60
# 8/8 [==============================] - 0s 2ms/step
# ==>> 507, dRLoss=0.631, dFLoss=0.651 gLoss=1.243, accR=76, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 508, dRLoss=0.641, dFLoss=0.665 gLoss=1.889, accR=81, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 509, dRLoss=0.639, dFLoss=0.665 gLoss=1.249, accR=75, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 510, dRLoss=0.637, dFLoss=0.658 gLoss=1.644, accR=77, accF=54
# 8/8 [==============================] - 0s 2ms/step
# ==>> 511, dRLoss=0.638, dFLoss=0.665 gLoss=1.220, accR=75, accF=56
# 8/8 [==============================] - 0s 2ms/step
# ==>> 512, dRLoss=0.644, dFLoss=0.651 gLoss=1.175, accR=78, accF=59
# 8/8 [==============================] - 0s 2ms/step
# ==>> 513, dRLoss=0.630, dFLoss=0.669 gLoss=1.536, accR=75, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 514, dRLoss=0.639, dFLoss=0.663 gLoss=1.502, accR=79, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 515, dRLoss=0.629, dFLoss=0.675 gLoss=1.852, accR=78, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 516, dRLoss=0.632, dFLoss=0.647 gLoss=1.688, accR=78, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 517, dRLoss=0.628, dFLoss=0.658 gLoss=1.250, accR=78, accF=56
# 8/8 [==============================] - 0s 2ms/step
# ==>> 518, dRLoss=0.644, dFLoss=0.674 gLoss=1.542, accR=72, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 519, dRLoss=0.638, dFLoss=0.681 gLoss=1.301, accR=77, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 520, dRLoss=0.645, dFLoss=0.662 gLoss=1.538, accR=75, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 521, dRLoss=0.640, dFLoss=0.664 gLoss=1.543, accR=73, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 522, dRLoss=0.636, dFLoss=0.694 gLoss=1.202, accR=78, accF=41
# 8/8 [==============================] - 0s 2ms/step
# ==>> 523, dRLoss=0.644, dFLoss=0.675 gLoss=1.244, accR=75, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 524, dRLoss=0.637, dFLoss=0.690 gLoss=1.396, accR=78, accF=45
# 8/8 [==============================] - 0s 2ms/step
# ==>> 525, dRLoss=0.644, dFLoss=0.681 gLoss=1.215, accR=76, accF=47
# 8/8 [==============================] - 0s 2ms/step
# ==>> 526, dRLoss=0.644, dFLoss=0.662 gLoss=1.438, accR=72, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 527, dRLoss=0.637, dFLoss=0.653 gLoss=1.122, accR=78, accF=54
# 8/8 [==============================] - 0s 2ms/step
# ==>> 528, dRLoss=0.645, dFLoss=0.675 gLoss=1.232, accR=74, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 529, dRLoss=0.639, dFLoss=0.682 gLoss=1.246, accR=74, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 530, dRLoss=0.643, dFLoss=0.660 gLoss=1.401, accR=75, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 531, dRLoss=0.650, dFLoss=0.643 gLoss=1.374, accR=71, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 532, dRLoss=0.630, dFLoss=0.678 gLoss=1.253, accR=78, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 533, dRLoss=0.632, dFLoss=0.688 gLoss=1.448, accR=77, accF=47
# 8/8 [==============================] - 0s 2ms/step
# ==>> 534, dRLoss=0.632, dFLoss=0.679 gLoss=1.265, accR=77, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 535, dRLoss=0.650, dFLoss=0.679 gLoss=1.847, accR=69, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 536, dRLoss=0.646, dFLoss=0.672 gLoss=1.406, accR=74, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 537, dRLoss=0.645, dFLoss=0.657 gLoss=1.099, accR=76, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 538, dRLoss=0.649, dFLoss=0.670 gLoss=0.944, accR=75, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 539, dRLoss=0.638, dFLoss=0.669 gLoss=1.288, accR=75, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 540, dRLoss=0.639, dFLoss=0.665 gLoss=1.128, accR=76, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 541, dRLoss=0.643, dFLoss=0.658 gLoss=1.369, accR=74, accF=60
# 8/8 [==============================] - 0s 1ms/step
# ==>> 542, dRLoss=0.638, dFLoss=0.668 gLoss=1.111, accR=76, accF=59
# 8/8 [==============================] - 0s 2ms/step
# ==>> 543, dRLoss=0.640, dFLoss=0.662 gLoss=1.242, accR=77, accF=56
# 8/8 [==============================] - 0s 2ms/step
# ==>> 544, dRLoss=0.638, dFLoss=0.668 gLoss=1.292, accR=75, accF=59
# 8/8 [==============================] - 0s 2ms/step
# ==>> 545, dRLoss=0.644, dFLoss=0.642 gLoss=1.251, accR=76, accF=61
# 8/8 [==============================] - 0s 2ms/step
# ==>> 546, dRLoss=0.643, dFLoss=0.655 gLoss=1.102, accR=73, accF=56
# 8/8 [==============================] - 0s 2ms/step
# ==>> 547, dRLoss=0.642, dFLoss=0.675 gLoss=1.103, accR=73, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 548, dRLoss=0.639, dFLoss=0.673 gLoss=1.194, accR=74, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 549, dRLoss=0.636, dFLoss=0.653 gLoss=1.286, accR=80, accF=60
# 8/8 [==============================] - 0s 2ms/step
# ==>> 550, dRLoss=0.637, dFLoss=0.666 gLoss=1.536, accR=77, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 551, dRLoss=0.657, dFLoss=0.647 gLoss=1.266, accR=73, accF=60
# 8/8 [==============================] - 0s 2ms/step
# ==>> 552, dRLoss=0.642, dFLoss=0.641 gLoss=1.250, accR=73, accF=59
# 8/8 [==============================] - 0s 1ms/step
# ==>> 553, dRLoss=0.637, dFLoss=0.683 gLoss=0.943, accR=78, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 554, dRLoss=0.641, dFLoss=0.674 gLoss=1.388, accR=74, accF=54
# 8/8 [==============================] - 0s 1ms/step
# ==>> 555, dRLoss=0.643, dFLoss=0.655 gLoss=1.282, accR=73, accF=60
# 8/8 [==============================] - 0s 2ms/step
# ==>> 556, dRLoss=0.649, dFLoss=0.674 gLoss=1.015, accR=71, accF=53
# 8/8 [==============================] - 0s 1ms/step
# ==>> 557, dRLoss=0.650, dFLoss=0.678 gLoss=1.400, accR=75, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 558, dRLoss=0.644, dFLoss=0.678 gLoss=1.498, accR=73, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 559, dRLoss=0.647, dFLoss=0.670 gLoss=1.247, accR=74, accF=56
# 8/8 [==============================] - 0s 2ms/step
# ==>> 560, dRLoss=0.644, dFLoss=0.663 gLoss=1.268, accR=76, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 561, dRLoss=0.646, dFLoss=0.658 gLoss=1.077, accR=73, accF=54
# 8/8 [==============================] - 0s 2ms/step
# ==>> 562, dRLoss=0.645, dFLoss=0.670 gLoss=1.078, accR=73, accF=53
# 8/8 [==============================] - 0s 1ms/step
# ==>> 563, dRLoss=0.645, dFLoss=0.678 gLoss=1.112, accR=70, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 564, dRLoss=0.650, dFLoss=0.675 gLoss=0.918, accR=77, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 565, dRLoss=0.661, dFLoss=0.698 gLoss=1.539, accR=71, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 566, dRLoss=0.648, dFLoss=0.680 gLoss=1.562, accR=73, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 567, dRLoss=0.649, dFLoss=0.655 gLoss=1.030, accR=73, accF=62
# 8/8 [==============================] - 0s 1ms/step
# ==>> 568, dRLoss=0.650, dFLoss=0.657 gLoss=1.274, accR=74, accF=56
# 8/8 [==============================] - 0s 2ms/step
# ==>> 569, dRLoss=0.649, dFLoss=0.658 gLoss=1.115, accR=72, accF=56
# 8/8 [==============================] - 0s 2ms/step
# ==>> 570, dRLoss=0.654, dFLoss=0.671 gLoss=0.964, accR=68, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 571, dRLoss=0.652, dFLoss=0.662 gLoss=1.361, accR=75, accF=56
# 8/8 [==============================] - 0s 1ms/step
# ==>> 572, dRLoss=0.644, dFLoss=0.661 gLoss=1.241, accR=75, accF=57
# 8/8 [==============================] - 0s 1ms/step
# ==>> 573, dRLoss=0.650, dFLoss=0.673 gLoss=1.636, accR=73, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 574, dRLoss=0.645, dFLoss=0.669 gLoss=1.348, accR=73, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 575, dRLoss=0.651, dFLoss=0.656 gLoss=0.948, accR=73, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 576, dRLoss=0.644, dFLoss=0.667 gLoss=1.271, accR=77, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 577, dRLoss=0.656, dFLoss=0.666 gLoss=1.592, accR=71, accF=58
# 8/8 [==============================] - 0s 2ms/step
# ==>> 578, dRLoss=0.648, dFLoss=0.658 gLoss=1.342, accR=75, accF=60
# 8/8 [==============================] - 0s 2ms/step
# ==>> 579, dRLoss=0.644, dFLoss=0.657 gLoss=1.220, accR=71, accF=60
# 8/8 [==============================] - 0s 2ms/step
# ==>> 580, dRLoss=0.649, dFLoss=0.644 gLoss=0.946, accR=73, accF=67
# 8/8 [==============================] - 0s 2ms/step
# ==>> 581, dRLoss=0.638, dFLoss=0.669 gLoss=1.296, accR=76, accF=54
# 8/8 [==============================] - 0s 2ms/step
# ==>> 582, dRLoss=0.643, dFLoss=0.649 gLoss=1.165, accR=72, accF=61
# 8/8 [==============================] - 0s 2ms/step
# ==>> 583, dRLoss=0.649, dFLoss=0.658 gLoss=1.120, accR=71, accF=56
# 8/8 [==============================] - 0s 2ms/step
# ==>> 584, dRLoss=0.644, dFLoss=0.682 gLoss=1.211, accR=71, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 585, dRLoss=0.643, dFLoss=0.682 gLoss=1.157, accR=77, accF=51
# 8/8 [==============================] - 0s 1ms/step
# ==>> 586, dRLoss=0.652, dFLoss=0.663 gLoss=1.482, accR=71, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 587, dRLoss=0.643, dFLoss=0.659 gLoss=1.254, accR=73, accF=60
# 8/8 [==============================] - 0s 2ms/step
# ==>> 588, dRLoss=0.645, dFLoss=0.659 gLoss=1.296, accR=74, accF=59
# 8/8 [==============================] - 0s 2ms/step
# ==>> 589, dRLoss=0.650, dFLoss=0.678 gLoss=1.090, accR=74, accF=56
# 8/8 [==============================] - 0s 2ms/step
# ==>> 590, dRLoss=0.653, dFLoss=0.664 gLoss=1.312, accR=72, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 591, dRLoss=0.646, dFLoss=0.679 gLoss=0.946, accR=73, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 592, dRLoss=0.654, dFLoss=0.656 gLoss=1.083, accR=69, accF=59
# 8/8 [==============================] - 0s 2ms/step
# ==>> 593, dRLoss=0.648, dFLoss=0.652 gLoss=1.184, accR=70, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 594, dRLoss=0.650, dFLoss=0.641 gLoss=1.144, accR=75, accF=59
# 8/8 [==============================] - 0s 2ms/step
# ==>> 595, dRLoss=0.652, dFLoss=0.658 gLoss=1.097, accR=70, accF=59
# 8/8 [==============================] - 0s 2ms/step
# ==>> 596, dRLoss=0.653, dFLoss=0.659 gLoss=1.618, accR=72, accF=51
# 8/8 [==============================] - 0s 1ms/step
# ==>> 597, dRLoss=0.649, dFLoss=0.655 gLoss=1.079, accR=71, accF=59
# 8/8 [==============================] - 0s 2ms/step
# ==>> 598, dRLoss=0.649, dFLoss=0.681 gLoss=1.342, accR=73, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 599, dRLoss=0.649, dFLoss=0.665 gLoss=1.129, accR=74, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 600, dRLoss=0.657, dFLoss=0.665 gLoss=1.234, accR=71, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 601, dRLoss=0.642, dFLoss=0.647 gLoss=0.990, accR=75, accF=54
# 8/8 [==============================] - 0s 2ms/step
# ==>> 602, dRLoss=0.653, dFLoss=0.640 gLoss=1.279, accR=71, accF=64
# 8/8 [==============================] - 0s 2ms/step
# ==>> 603, dRLoss=0.649, dFLoss=0.656 gLoss=1.056, accR=72, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 604, dRLoss=0.647, dFLoss=0.650 gLoss=1.167, accR=72, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 605, dRLoss=0.663, dFLoss=0.664 gLoss=1.235, accR=72, accF=56
# 8/8 [==============================] - 0s 2ms/step
# ==>> 606, dRLoss=0.639, dFLoss=0.677 gLoss=1.336, accR=73, accF=49
# 8/8 [==============================] - 0s 2ms/step
# ==>> 607, dRLoss=0.630, dFLoss=0.658 gLoss=1.102, accR=75, accF=63
# 8/8 [==============================] - 0s 2ms/step
# ==>> 608, dRLoss=0.652, dFLoss=0.668 gLoss=1.355, accR=71, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 609, dRLoss=0.653, dFLoss=0.666 gLoss=0.963, accR=73, accF=54
# 8/8 [==============================] - 0s 2ms/step
# ==>> 610, dRLoss=0.634, dFLoss=0.668 gLoss=1.487, accR=76, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 611, dRLoss=0.644, dFLoss=0.667 gLoss=1.016, accR=74, accF=57
# 8/8 [==============================] - 0s 2ms/step
# ==>> 612, dRLoss=0.648, dFLoss=0.663 gLoss=1.083, accR=74, accF=54
# 8/8 [==============================] - 0s 2ms/step
# ==>> 613, dRLoss=0.643, dFLoss=0.676 gLoss=1.296, accR=74, accF=58
# ...
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2573, dRLoss=0.696, dFLoss=0.694 gLoss=0.714, accR=53, accF=49
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2574, dRLoss=0.701, dFLoss=0.690 gLoss=0.718, accR=47, accF=49
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2575, dRLoss=0.689, dFLoss=0.701 gLoss=0.716, accR=55, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2576, dRLoss=0.693, dFLoss=0.693 gLoss=0.720, accR=54, accF=50
# 8/8 [==============================] - 0s 1ms/step
# ==>> 2577, dRLoss=0.695, dFLoss=0.683 gLoss=0.713, accR=49, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2578, dRLoss=0.696, dFLoss=0.692 gLoss=0.716, accR=50, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2579, dRLoss=0.685, dFLoss=0.688 gLoss=0.711, accR=54, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2580, dRLoss=0.695, dFLoss=0.688 gLoss=0.713, accR=50, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2581, dRLoss=0.683, dFLoss=0.692 gLoss=0.719, accR=53, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2582, dRLoss=0.693, dFLoss=0.701 gLoss=0.716, accR=53, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2583, dRLoss=0.693, dFLoss=0.699 gLoss=0.719, accR=53, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2584, dRLoss=0.697, dFLoss=0.695 gLoss=0.720, accR=48, accF=50
# 8/8 [==============================] - 0s 1ms/step
# ==>> 2585, dRLoss=0.690, dFLoss=0.709 gLoss=0.726, accR=51, accF=45
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2586, dRLoss=0.692, dFLoss=0.694 gLoss=0.714, accR=52, accF=47
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2587, dRLoss=0.689, dFLoss=0.696 gLoss=0.710, accR=53, accF=49
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2588, dRLoss=0.703, dFLoss=0.699 gLoss=0.710, accR=44, accF=45
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2589, dRLoss=0.696, dFLoss=0.686 gLoss=0.719, accR=52, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2590, dRLoss=0.706, dFLoss=0.689 gLoss=0.720, accR=43, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2591, dRLoss=0.698, dFLoss=0.695 gLoss=0.716, accR=50, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2592, dRLoss=0.696, dFLoss=0.697 gLoss=0.715, accR=51, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2593, dRLoss=0.698, dFLoss=0.685 gLoss=0.720, accR=50, accF=54
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2594, dRLoss=0.681, dFLoss=0.683 gLoss=0.718, accR=60, accF=56
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2595, dRLoss=0.691, dFLoss=0.693 gLoss=0.721, accR=50, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2596, dRLoss=0.704, dFLoss=0.686 gLoss=0.725, accR=47, accF=56
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2597, dRLoss=0.682, dFLoss=0.703 gLoss=0.723, accR=58, accF=44
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2598, dRLoss=0.684, dFLoss=0.698 gLoss=0.715, accR=54, accF=47
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2599, dRLoss=0.701, dFLoss=0.693 gLoss=0.707, accR=46, accF=49
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2600, dRLoss=0.694, dFLoss=0.689 gLoss=0.714, accR=57, accF=54
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2601, dRLoss=0.701, dFLoss=0.683 gLoss=0.715, accR=47, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2602, dRLoss=0.697, dFLoss=0.699 gLoss=0.711, accR=50, accF=42
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2603, dRLoss=0.689, dFLoss=0.688 gLoss=0.712, accR=53, accF=55
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2604, dRLoss=0.690, dFLoss=0.689 gLoss=0.723, accR=52, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2605, dRLoss=0.701, dFLoss=0.690 gLoss=0.710, accR=49, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2606, dRLoss=0.695, dFLoss=0.696 gLoss=0.710, accR=51, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2607, dRLoss=0.694, dFLoss=0.683 gLoss=0.717, accR=50, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2608, dRLoss=0.701, dFLoss=0.680 gLoss=0.716, accR=47, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2609, dRLoss=0.696, dFLoss=0.702 gLoss=0.723, accR=50, accF=45
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2610, dRLoss=0.687, dFLoss=0.685 gLoss=0.707, accR=56, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2611, dRLoss=0.698, dFLoss=0.696 gLoss=0.717, accR=49, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2612, dRLoss=0.694, dFLoss=0.704 gLoss=0.702, accR=52, accF=45
# 8/8 [==============================] - 0s 1ms/step
# ==>> 2613, dRLoss=0.688, dFLoss=0.690 gLoss=0.708, accR=54, accF=53
# 8/8 [==============================] - 0s 1ms/step
# ==>> 2614, dRLoss=0.686, dFLoss=0.700 gLoss=0.715, accR=55, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2615, dRLoss=0.689, dFLoss=0.697 gLoss=0.732, accR=53, accF=47
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2616, dRLoss=0.686, dFLoss=0.685 gLoss=0.723, accR=57, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2617, dRLoss=0.693, dFLoss=0.691 gLoss=0.720, accR=49, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2618, dRLoss=0.698, dFLoss=0.691 gLoss=0.717, accR=50, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2619, dRLoss=0.694, dFLoss=0.702 gLoss=0.708, accR=50, accF=46
# 8/8 [==============================] - 0s 1ms/step
# ==>> 2620, dRLoss=0.702, dFLoss=0.700 gLoss=0.716, accR=48, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2621, dRLoss=0.683, dFLoss=0.700 gLoss=0.714, accR=58, accF=44
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2622, dRLoss=0.695, dFLoss=0.696 gLoss=0.727, accR=51, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2623, dRLoss=0.694, dFLoss=0.710 gLoss=0.713, accR=51, accF=47
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2624, dRLoss=0.695, dFLoss=0.692 gLoss=0.707, accR=51, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2625, dRLoss=0.695, dFLoss=0.690 gLoss=0.715, accR=52, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2626, dRLoss=0.682, dFLoss=0.694 gLoss=0.710, accR=58, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2627, dRLoss=0.695, dFLoss=0.690 gLoss=0.712, accR=50, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2628, dRLoss=0.702, dFLoss=0.706 gLoss=0.708, accR=47, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2629, dRLoss=0.692, dFLoss=0.700 gLoss=0.715, accR=50, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2630, dRLoss=0.692, dFLoss=0.695 gLoss=0.712, accR=51, accF=47
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2631, dRLoss=0.684, dFLoss=0.697 gLoss=0.711, accR=53, accF=49
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2632, dRLoss=0.688, dFLoss=0.694 gLoss=0.708, accR=51, accF=51
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2633, dRLoss=0.692, dFLoss=0.688 gLoss=0.713, accR=51, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2634, dRLoss=0.688, dFLoss=0.700 gLoss=0.718, accR=55, accF=47
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2635, dRLoss=0.691, dFLoss=0.693 gLoss=0.721, accR=53, accF=49
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2636, dRLoss=0.682, dFLoss=0.689 gLoss=0.709, accR=60, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2637, dRLoss=0.692, dFLoss=0.695 gLoss=0.710, accR=50, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2638, dRLoss=0.699, dFLoss=0.685 gLoss=0.730, accR=47, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2639, dRLoss=0.693, dFLoss=0.696 gLoss=0.710, accR=53, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2640, dRLoss=0.701, dFLoss=0.700 gLoss=0.711, accR=45, accF=42
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2641, dRLoss=0.693, dFLoss=0.704 gLoss=0.713, accR=53, accF=49
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2642, dRLoss=0.692, dFLoss=0.686 gLoss=0.714, accR=52, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2643, dRLoss=0.699, dFLoss=0.710 gLoss=0.706, accR=50, accF=40
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2644, dRLoss=0.690, dFLoss=0.685 gLoss=0.714, accR=53, accF=54
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2645, dRLoss=0.698, dFLoss=0.694 gLoss=0.705, accR=49, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2646, dRLoss=0.692, dFLoss=0.697 gLoss=0.721, accR=51, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2647, dRLoss=0.696, dFLoss=0.699 gLoss=0.703, accR=53, accF=44
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2648, dRLoss=0.700, dFLoss=0.704 gLoss=0.708, accR=48, accF=40
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2649, dRLoss=0.695, dFLoss=0.696 gLoss=0.703, accR=52, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2650, dRLoss=0.694, dFLoss=0.701 gLoss=0.707, accR=50, accF=49
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2651, dRLoss=0.690, dFLoss=0.699 gLoss=0.715, accR=55, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2652, dRLoss=0.689, dFLoss=0.708 gLoss=0.711, accR=54, accF=42
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2653, dRLoss=0.699, dFLoss=0.700 gLoss=0.707, accR=49, accF=44
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2654, dRLoss=0.689, dFLoss=0.700 gLoss=0.711, accR=56, accF=47
# 8/8 [==============================] - 0s 1ms/step
# ==>> 2655, dRLoss=0.687, dFLoss=0.696 gLoss=0.722, accR=55, accF=47
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2656, dRLoss=0.698, dFLoss=0.696 gLoss=0.718, accR=50, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2657, dRLoss=0.685, dFLoss=0.694 gLoss=0.713, accR=50, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2658, dRLoss=0.691, dFLoss=0.696 gLoss=0.698, accR=49, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2659, dRLoss=0.701, dFLoss=0.697 gLoss=0.707, accR=50, accF=48
# 8/8 [==============================] - 0s 1ms/step
# ==>> 2660, dRLoss=0.700, dFLoss=0.695 gLoss=0.705, accR=50, accF=45
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2661, dRLoss=0.690, dFLoss=0.703 gLoss=0.720, accR=54, accF=45
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2662, dRLoss=0.695, dFLoss=0.703 gLoss=0.714, accR=51, accF=43
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2663, dRLoss=0.694, dFLoss=0.691 gLoss=0.705, accR=51, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2664, dRLoss=0.692, dFLoss=0.695 gLoss=0.711, accR=51, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2665, dRLoss=0.698, dFLoss=0.691 gLoss=0.712, accR=48, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2666, dRLoss=0.691, dFLoss=0.699 gLoss=0.713, accR=51, accF=49
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2667, dRLoss=0.696, dFLoss=0.708 gLoss=0.714, accR=46, accF=47
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2668, dRLoss=0.692, dFLoss=0.696 gLoss=0.707, accR=53, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2669, dRLoss=0.699, dFLoss=0.697 gLoss=0.710, accR=51, accF=48
# 8/8 [==============================] - 0s 1ms/step
# ==>> 2670, dRLoss=0.697, dFLoss=0.694 gLoss=0.714, accR=47, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2671, dRLoss=0.703, dFLoss=0.705 gLoss=0.716, accR=45, accF=41
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2672, dRLoss=0.687, dFLoss=0.699 gLoss=0.715, accR=55, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2673, dRLoss=0.692, dFLoss=0.696 gLoss=0.713, accR=52, accF=47
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2674, dRLoss=0.701, dFLoss=0.691 gLoss=0.705, accR=45, accF=52
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2675, dRLoss=0.697, dFLoss=0.703 gLoss=0.714, accR=54, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2676, dRLoss=0.700, dFLoss=0.692 gLoss=0.705, accR=48, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2677, dRLoss=0.702, dFLoss=0.705 gLoss=0.709, accR=46, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2678, dRLoss=0.700, dFLoss=0.706 gLoss=0.711, accR=47, accF=41
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2679, dRLoss=0.702, dFLoss=0.698 gLoss=0.704, accR=46, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2680, dRLoss=0.697, dFLoss=0.696 gLoss=0.709, accR=50, accF=49
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2681, dRLoss=0.689, dFLoss=0.701 gLoss=0.702, accR=53, accF=44
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2682, dRLoss=0.695, dFLoss=0.700 gLoss=0.698, accR=52, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2683, dRLoss=0.700, dFLoss=0.697 gLoss=0.708, accR=51, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2684, dRLoss=0.697, dFLoss=0.702 gLoss=0.709, accR=51, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2685, dRLoss=0.697, dFLoss=0.707 gLoss=0.706, accR=49, accF=42
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2686, dRLoss=0.700, dFLoss=0.696 gLoss=0.719, accR=49, accF=47
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2687, dRLoss=0.694, dFLoss=0.695 gLoss=0.713, accR=56, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2688, dRLoss=0.697, dFLoss=0.699 gLoss=0.711, accR=49, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2689, dRLoss=0.694, dFLoss=0.708 gLoss=0.715, accR=51, accF=40
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2690, dRLoss=0.702, dFLoss=0.696 gLoss=0.713, accR=50, accF=47
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2691, dRLoss=0.693, dFLoss=0.698 gLoss=0.723, accR=53, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2692, dRLoss=0.693, dFLoss=0.695 gLoss=0.711, accR=45, accF=50
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2693, dRLoss=0.698, dFLoss=0.690 gLoss=0.720, accR=46, accF=53
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2694, dRLoss=0.705, dFLoss=0.701 gLoss=0.715, accR=44, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2695, dRLoss=0.698, dFLoss=0.704 gLoss=0.709, accR=50, accF=44
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2696, dRLoss=0.688, dFLoss=0.705 gLoss=0.712, accR=53, accF=42
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2697, dRLoss=0.693, dFLoss=0.700 gLoss=0.713, accR=54, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2698, dRLoss=0.702, dFLoss=0.696 gLoss=0.707, accR=44, accF=49
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2699, dRLoss=0.701, dFLoss=0.710 gLoss=0.723, accR=55, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2700, dRLoss=0.689, dFLoss=0.696 gLoss=0.709, accR=51, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2701, dRLoss=0.696, dFLoss=0.698 gLoss=0.702, accR=52, accF=46
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2702, dRLoss=0.691, dFLoss=0.695 gLoss=0.708, accR=56, accF=48
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2703, dRLoss=0.702, dFLoss=0.705 gLoss=0.713, accR=45, accF=44
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2704, dRLoss=0.705, dFLoss=0.696 gLoss=0.720, accR=47, accF=47
# 8/8 [==============================] - 0s 1ms/step
# ==>> 2705, dRLoss=0.692, dFLoss=0.697 gLoss=0.711, accR=54, accF=44
# 8/8 [==============================] - 0s 2ms/step
# ==>> 2706, dRLoss=0.693, dFLoss=0.695 gLoss=0.714, accR=51, accF=47
# 8/8 [==============================] - 0s 2ms/step

# %%
models = {'GAN': ['GAN', False, synthesizer.generator]}

# %% [markdown]
# ```
# By setting a seed, you can ensure that the randomness introduced
# by the use of random number generators is consistent across different runs of your code,
# which can help make your results more reliable and reproducible
# ```

# %%
np.random.seed(3) # used for retestability

num_rows_gen = 1000 #quante righe verranno generate generate
noise = np.random.normal(0, 1, (num_rows_gen, input_noise))

[model_name, with_class, generator_model] = models['GAN']

X = generator_model.predict(noise)

# %%
# Create a dataframe with generated samples, so can be used for evaluation later
gen_samples = pd.DataFrame(X, columns=data_columns)

# %%
print(df.shape)
print(gen_samples.shape)

# %%
df.head()

# %%
gen_samples.head()

# %% [markdown]
# #Valutazione

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 6))
sns.heatmap(df.corr(), annot=False, ax=ax[0], cmap="Blues")
sns.heatmap(gen_samples.corr(), annot=False, ax=ax[1], cmap="Blues")
ax[0].set_title("Dati reali")
ax[1].set_title("Dati generati")

# %%
real_data = df.to_numpy()
generated_data = gen_samples.to_numpy()

# %%
from scipy.stats import wasserstein_distance

# Flatten the arrays for 1D distribution
real_flat = real_data.flatten()
generated_flat = generated_data.flatten()

# Compute Wasserstein distance
w_distance = wasserstein_distance(real_flat, generated_flat)

print('Wasserstein Distance delle distribuzioni:', w_distance)

# %% [markdown]
# ```
# Interpretation can depend on the scale and nature of your data, but in general:
# ## Closer to 0: Indicates a smaller difference between distributions.
# ```

# %%
real = df['FlowDuration'].to_numpy()
gen = gen_samples['FlowDuration'].to_numpy()

w_dist_feature = wasserstein_distance(real, gen)
print("Wasserstein Distance per la feature FlowDuration:", w_dist_feature)

# %% [markdown]
# ```
# # Wasserstein Distance for BwdPacketLengthStd feature: 0.0008046525194385199
# # Wasserstein Distance for FlowDuration feature: 0.0003101878491190463
# # Wasserstein Distance for PacketLengthVariance feature: 0.023556970948095415
# # Wasserstein Distance for DstPort feature: 0.0016220070848744499
# ```

# %%
from scipy.stats import ks_2samp


column_to_check = 0

# Perform the KS test for the selected column
ks_statistic, ks_p_value = ks_2samp(real_data[:, column_to_check], generated_data[:, column_to_check])

# Print the results
print(f"KS Statistic: {ks_statistic}")
print(f"P-value: {ks_p_value}")

# Interpret the results
#A higher alpha means you are more lenient in terms of what level of evidence you require to reject the null hypothesis.
alpha = 0.1  # significance level
if ks_p_value > alpha:
    print("Le distribuzioni sono simili (fail to reject the null hypothesis)")
else:
    print("Le distribuzioni sono differenti (reject the null hypothesis)")

# %%
# Choose the column you want to check
# 0 = FlowDuration
# 1 = BwdPacketLengthStd
# 2 = PacketLengthVariance
# 3 = DstPort

# %%
column_to_compare = 0

# Extract the selected column for each array
real_column = real_data[:, column_to_compare]
generated_column = generated_data[:, column_to_compare]

# Plot the KDE for both distributions
sns.kdeplot(real_column, label='Dati reali', fill=True)
sns.kdeplot(generated_column, label='Dati generati', fill=True)

# Add labels and legend
plt.title(f'Confronto distribuzioni della feature: {df.columns[column_to_compare]}')
plt.xlabel('Valori')
plt.ylabel('Densità')
plt.legend()
#salva in Drive
#images_dir = '/content/drive/MyDrive/Colab Notebooks/progettoTesi/grafici_pdf'
#plt.savefig(f"{images_dir}/distributionFeatureFlowDuration_genWGAN_t2.pdf", dpi=200, format='pdf') ###!!!!!!!!!!!!!! CAMBIARE TENTATIVI CON N°
plt.show()

# %%
from sklearn.metrics import mean_squared_error

real_data_first_column = real_data[:, 0]
gen_data_first_column = generated_data[:, 0]

# Downsample gen_data_first_column to match the size of real_data_first_column - 736
downsampled_gen_data_first_column = np.random.choice(gen_data_first_column, size=(len(real_data_first_column),), replace=False)

# Calculate the Mean Squared Error
mse = mean_squared_error(real_data_first_column, downsampled_gen_data_first_column)

print(f"Mean Squared Error: {mse}")

# %% [markdown]
# ```
# # 0 --> Mean Squared Error: 2.803826646413654e-07
# # 1 --> Mean Squared Error: 3.4297804631933104e-06
# # 2 --> Mean Squared Error: 0.011631663888692856
# # 3 --> Mean Squared Error: 4.149306732870173e-06
# ```

# %% [markdown]
# ```
# Interpretation:
#
# *   A smaller MSE indicates that the generated data is closer to the real data in terms of the selected feature.
# *  Closer to 0 suggests better performance for that specific feature.
#
#
# ```

# %%
def gaussian_kernel(x, y, sigma=1.0):
    # Gaussian kernel function
    return np.exp(-np.linalg.norm(x - y) ** 2 / (2 * (sigma ** 2)))

def mmd(real_data, generated_data, kernel=gaussian_kernel):
    m = len(real_data)
    n = len(generated_data)

    # Compute the MMD statistic
    mmd_statistic = 0.0
    for i in range(m):
        for j in range(m):
            mmd_statistic += kernel(real_data[i], real_data[j])

    for i in range(n):
        for j in range(n):
            mmd_statistic += kernel(generated_data[i], generated_data[j])

    for i in range(m):
        for j in range(n):
            mmd_statistic -= 2 * kernel(real_data[i], generated_data[j])

    mmd_statistic /= (m * (m - 1)) + (n * (n - 1)) - 2 * m * n
    return mmd_statistic


mmd_statistic = mmd(real_data[:, 0], generated_data[:, 0])

print("MMD:", mmd_statistic)

# %% [markdown]
# ```
# you would want the MMD to be close to zero, as it implies that the generated samples are very similar to the real data.
#
# Negative MMD: The MMD itself doesn't have a fixed sign, so negative values are not uncommon. The magnitude is more important,
# and in this case, the small magnitude indicates similarity.
# ```

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 6))
ax[0].scatter(df.iloc[:, 0], df.iloc[:, 1])
ax[1].scatter(gen_samples.iloc[:, 0], gen_samples.iloc[:, 1])
ax[0].set_title("Dati reali")
ax[1].set_title("Dati generati")

# %% [markdown]
# #Vecchi metodi valutazione
# *   https://github.com/sdv-dev/SDV
# *   https://docs.sdv.dev/sdv

# %%
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(df)

# %%
quality_report = evaluate_quality(
    real_data=df,
    synthetic_data=gen_samples,
    metadata=metadata)

# %%
diagnostic_report = run_diagnostic(
    real_data=df,
    synthetic_data=gen_samples,
    metadata=metadata)
