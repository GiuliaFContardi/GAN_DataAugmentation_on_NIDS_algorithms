# %% [markdown]
# ## **Load in data**

# %%
# link & mount to google drive to import data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
X_train = pd.read_csv('/content/drive/My Drive/Colab Notebooks/progettoTesi/Dataset2017/improved/Pre-processed_versions/terzoPreprocessing/X_train_35.csv')
y_train = pd.read_csv('/content/drive/My Drive/Colab Notebooks/progettoTesi/Dataset2017/improved/Pre-processed_versions/terzoPreprocessing/y_train_35.csv')

print(X_train.shape)
print(y_train.shape)
# Out:
# (1469838, 35)
# (1469838, 6)

# %%
data_columns = X_train.columns
labels_columns = y_train.columns

# %%
print(labels_columns)
# Out:
# Index(['L_BENIGN', 'L_Infiltration_Portscan', 'L_DDoS', 'L_DoS',
#        'L_BruteForce', 'L_Botnet'],
#       dtype='object')

# %%
pd.options.display.float_format = '{:,.20f}'.format

# %%
df = pd.concat([X_train, y_train], axis=1)

# %%
df
# Out:
#                   FlowDuration     BwdPacketLengthStd                DstPort  \
# 0       0.12336963641757420218 0.01609175409250790043 0.00679088647774260014
# 1       0.10006393583493169985 0.45023456904328618133 0.00122083352408849997
# 2       0.02394830893204100142 0.12327550179217569570 0.00676036563964039963
# 3       0.08757281885598709736 0.32622330025341017556 0.00122083352408849997
# 4       0.07373842684346060272 0.11576662688246899813 0.00676036563964039963
# ...                        ...                    ...                    ...
# 1469833 0.00000249166672895833 0.00000000000000000000 0.00080880220970860005
# 1469834 0.00019777500494430001 0.00000000000000000000 0.00080880220970860005
# 1469835 0.00000191666671458333 0.00000000000000000000 0.00080880220970860005
# 1469836 0.00169853337579659990 0.00000000000000000000 0.00080880220970860005
# 1469837 0.00026101667319200001 0.00000000000000000000 0.00080880220970860005
#
#          TotalLengthofFwdPacket             FlowIATMax   PacketLengthVariance  \
# 0        0.00057947583310719996 0.12170791145253699594 0.01307735349845779924
# 1        0.00000155397112659488 0.09944774544250239989 0.20083179857744729024
# 2        0.00004320039731933765 0.01922706761999979849 0.01452055111006299998
# 3        0.00000155397112659488 0.08290614210861499411 0.13631339619087889936
# 4        0.00013713795192189999 0.04115367455731189922 0.04065396673467199656
# ...                         ...                    ...                    ...
# 1469833  0.00000637128161903901 0.00000208333795139913 0.00001853890104230302
# 1469834  0.00000458421482345489 0.00019777543840220001 0.00009591043702497580
# 1469835  0.00000590509028106054 0.00000149166997320177 0.00002301850488599420
# 1469836  0.00000357413359116822 0.00169853709842390007 0.00012097200447480000
# 1469837  0.00000380722926015745 0.00026101724525479997 0.00037192818940050000
#
#                PacketLengthStd     BwdPacketLengthMax          FlowPackets/s  \
# 0       0.11435625692745379767 0.01331285202252940024 0.00000100488187634421
# 1       0.44814260964278690436 0.37378392217101891193 0.00000035254699793876
# 2       0.12050124941287139457 0.11607782898105470371 0.00000242746764235071
# 3       0.36920644115572920363 0.29902713773681510734 0.00000040402185551578
# 4       0.20162828852785530387 0.22242703533026109142 0.00000696074463230835
# ...                        ...                    ...                    ...
# 1469833 0.00430568241307959995 0.00389144905273929986 0.00444443614811830014
# 1469834 0.00979338741319749941 0.00634920634920629976 0.00002808076549163792
# 1469835 0.00479776040314579960 0.00394265232974910004 0.00577199748674270003
# 1469836 0.01099872740251409999 0.00609318996415769958 0.00000326244633609694
# 1469837 0.01928543982906590071 0.00906298003072190071 0.00002127528162323929
#
#                   RSTFlagCount  ...        BwdHeaderLength  \
# 0       0.01052631578947360071  ... 0.50712059165087708390
# 1       0.00526315789473680035  ... 0.50235315689750015267
# 2       0.00000000000000000000  ... 0.50351445510665615579
# 3       0.00526315789473680035  ... 0.50265876168938328217
# 4       0.00000000000000000000  ... 0.54984414155613969832
# ...                        ...  ...                    ...
# 1469833 0.00000000000000000000  ... 0.50088625389646113106
# 1469834 0.00000000000000000000  ... 0.50076401197970787926
# 1469835 0.00000000000000000000  ... 0.50088625389646113106
# 1469836 0.00000000000000000000  ... 0.50076401197970787926
# 1469837 0.00000000000000000000  ... 0.50076401197970787926
#
#                    FwdIATTotal          FwdSegSizeMin        FWDInitWinBytes  \
# 0       0.12336959372282650660 0.45454545454545458583 0.12500190737773708705
# 1       0.10006394333439899702 0.45454545454545458583 0.12500190737773708705
# 2       0.02394831706580519831 0.45454545454545458583 0.12500190737773708705
# 3       0.08757282645954710121 0.45454545454545458583 0.12500190737773708705
# 4       0.07345465122424410520 0.72727272727272729291 0.44556343938353548673
# ...                        ...                    ...                    ...
# 1469833 0.00000038333333972222 0.18181818181818179547 0.00000000000000000000
# 1469834 0.00000000000000000000 0.18181818181818179547 0.00000000000000000000
# 1469835 0.00000040000000666667 0.18181818181818179547 0.00000000000000000000
# 1469836 0.00000000000000000000 0.18181818181818179547 0.00000000000000000000
# 1469837 0.00000000000000000000 0.18181818181818179547 0.00000000000000000000
#
#                       L_BENIGN  L_Infiltration_Portscan  \
# 0       1.00000000000000000000   0.00000000000000000000
# 1       0.00000000000000000000   0.00000000000000000000
# 2       1.00000000000000000000   0.00000000000000000000
# 3       0.00000000000000000000   0.00000000000000000000
# 4       1.00000000000000000000   0.00000000000000000000
# ...                        ...                      ...
# 1469833 1.00000000000000000000   0.00000000000000000000
# 1469834 1.00000000000000000000   0.00000000000000000000
# 1469835 1.00000000000000000000   0.00000000000000000000
# 1469836 1.00000000000000000000   0.00000000000000000000
# 1469837 1.00000000000000000000   0.00000000000000000000
#
#                         L_DDoS                  L_DoS           L_BruteForce  \
# 0       0.00000000000000000000 0.00000000000000000000 0.00000000000000000000
# 1       1.00000000000000000000 0.00000000000000000000 0.00000000000000000000
# 2       0.00000000000000000000 0.00000000000000000000 0.00000000000000000000
# 3       1.00000000000000000000 0.00000000000000000000 0.00000000000000000000
# 4       0.00000000000000000000 0.00000000000000000000 0.00000000000000000000
# ...                        ...                    ...                    ...
# 1469833 0.00000000000000000000 0.00000000000000000000 0.00000000000000000000
# 1469834 0.00000000000000000000 0.00000000000000000000 0.00000000000000000000
# 1469835 0.00000000000000000000 0.00000000000000000000 0.00000000000000000000
# 1469836 0.00000000000000000000 0.00000000000000000000 0.00000000000000000000
# 1469837 0.00000000000000000000 0.00000000000000000000 0.00000000000000000000
#
#                       L_Botnet
# 0       0.00000000000000000000
# 1       0.00000000000000000000
# 2       0.00000000000000000000
# 3       0.00000000000000000000
# 4       0.00000000000000000000
# ...                        ...
# 1469833 0.00000000000000000000
# 1469834 0.00000000000000000000
# 1469835 0.00000000000000000000
# 1469836 0.00000000000000000000
# 1469837 0.00000000000000000000
#
# [1469838 rows x 41 columns]

# %%
#preparo il dataframe in np array
data = X_train.to_numpy()
label_data = y_train.to_numpy()

merged_data = df.to_numpy()

# %% [markdown]
# ```
# BENIGN                   1594422
# Infiltration_Portscan     230853
# DoS                       171620
# DDoS                       95133
# BruteForce                  7005
# Botnet                       736
# ```

# %% [markdown]
# ## **Define model architecture**

# %% [markdown]
# ## Import

# %% [markdown]
# #### basic

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
# Allow matplotlib images to render immediately.
# %matplotlib inline

import seaborn as sns

from tensorflow.keras.layers import Input, Dense, Dropout, LeakyReLU, BatchNormalization
from tensorflow.keras import Model
from tensorflow.keras.models import Sequential

# %% [markdown]
# #### SDV import

# %%
# !pip install sdv
# %pip install sdmetrics
from sdv.metadata import SingleTableMetadata
from sdv.evaluation.single_table import evaluate_quality
from sdv.evaluation.single_table import run_diagnostic
# Out:
# Collecting sdv
#   Downloading sdv-1.10.0-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.2/143.2 kB 4.4 MB/s eta 0:00:00
# Collecting boto3<2,>=1.15.0 (from sdv)
#   Downloading boto3-1.34.44-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 21.0 MB/s eta 0:00:00
# Collecting botocore<2,>=1.18 (from sdv)
#   Downloading botocore-1.34.44-py3-none-any.whl (12.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 90.2 MB/s eta 0:00:00
# Requirement already satisfied: cloudpickle<3.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from sdv) (2.2.1)
# Requirement already satisfied: graphviz<1,>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from sdv) (0.20.1)
# Requirement already satisfied: tqdm<5,>=4.15 in /usr/local/lib/python3.10/dist-packages (from sdv) (4.66.2)
# Collecting copulas<0.10,>=0.9.0 (from sdv)
#   Downloading copulas-0.9.2-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 8.2 MB/s eta 0:00:00
# Collecting ctgan<0.10,>=0.9.0 (from sdv)
#   Downloading ctgan-0.9.0-py2.py3-none-any.whl (27 kB)
# Collecting deepecho<0.6,>=0.5 (from sdv)
#   Downloading deepecho-0.5.0-py2.py3-none-any.whl (29 kB)
# Collecting rdt<2,>=1.9.0 (from sdv)
#   Downloading rdt-1.9.2-py2.py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 10.9 MB/s eta 0:00:00
# Collecting sdmetrics<0.14,>=0.13.0 (from sdv)
#   Downloading sdmetrics-0.13.0-py2.py3-none-any.whl (170 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.7/170.7 kB 21.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1.23.3 in /usr/local/lib/python3.10/dist-packages (from sdv) (1.25.2)
# Requirement already satisfied: pandas>=1.3.4 in /usr/local/lib/python3.10/dist-packages (from sdv) (1.5.3)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2,>=1.15.0->sdv)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3<2,>=1.15.0->sdv)
#   Downloading s3transfer-0.10.0-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<2,>=1.18->sdv) (2.8.2)
# Requirement already satisfied: urllib3<2.1,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<2,>=1.18->sdv) (2.0.7)
# Requirement already satisfied: matplotlib<4,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from copulas<0.10,>=0.9.0->sdv) (3.7.1)
# Requirement already satisfied: scipy<2,>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from copulas<0.10,>=0.9.0->sdv) (1.11.4)
# Requirement already satisfied: scikit-learn<2,>=1.1.3 in /usr/local/lib/python3.10/dist-packages (from ctgan<0.10,>=0.9.0->sdv) (1.2.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from ctgan<0.10,>=0.9.0->sdv) (2.1.0+cu121)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.4->sdv) (2023.4)
# Collecting Faker<20,>=17 (from rdt<2,>=1.9.0->sdv)
#   Downloading Faker-19.13.0-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 84.3 MB/s eta 0:00:00
# Requirement already satisfied: plotly<6,>=5.10.0 in /usr/local/lib/python3.10/dist-packages (from sdmetrics<0.14,>=0.13.0->sdv) (5.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdv) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly<6,>=5.10.0->sdmetrics<0.14,>=0.13.0->sdv) (8.2.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<2,>=1.18->sdv) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=1.1.3->ctgan<0.10,>=0.9.0->sdv) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=1.1.3->ctgan<0.10,>=0.9.0->sdv) (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan<0.10,>=0.9.0->sdv) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan<0.10,>=0.9.0->sdv) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan<0.10,>=0.9.0->sdv) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan<0.10,>=0.9.0->sdv) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan<0.10,>=0.9.0->sdv) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan<0.10,>=0.9.0->sdv) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->ctgan<0.10,>=0.9.0->sdv) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->ctgan<0.10,>=0.9.0->sdv) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->ctgan<0.10,>=0.9.0->sdv) (1.3.0)
# Installing collected packages: jmespath, Faker, botocore, s3transfer, rdt, deepecho, copulas, sdmetrics, ctgan, boto3, sdv
# Successfully installed Faker-19.13.0 boto3-1.34.44 botocore-1.34.44 copulas-0.9.2 ctgan-0.9.0 deepecho-0.5.0 jmespath-1.0.1 rdt-1.9.2 s3transfer-0.10.0 sdmetrics-0.13.0 sdv-1.10.0
# Requirement already satisfied: sdmetrics in /usr/local/lib/python3.10/dist-packages (0.13.0)
# Requirement already satisfied: copulas<0.10,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from sdmetrics) (0.9.2)
# Requirement already satisfied: tqdm<5,>=4.15 in /usr/local/lib/python3.10/dist-packages (from sdmetrics) (4.66.2)
# Requirement already satisfied: plotly<6,>=5.10.0 in /usr/local/lib/python3.10/dist-packages (from sdmetrics) (5.15.0)
# Requirement already satisfied: scikit-learn<2,>=0.24 in /usr/local/lib/python3.10/dist-packages (from sdmetrics) (1.2.2)
# Requirement already satisfied: numpy<2,>=1.23.3 in /usr/local/lib/python3.10/dist-packages (from sdmetrics) (1.25.2)
# Requirement already satisfied: scipy<2,>=1.9.2 in /usr/local/lib/python3.10/dist-packages (from sdmetrics) (1.11.4)
# Requirement already satisfied: pandas>=1.3.4 in /usr/local/lib/python3.10/dist-packages (from sdmetrics) (1.5.3)
# Requirement already satisfied: matplotlib<4,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from copulas<0.10,>=0.9.0->sdmetrics) (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.4->sdmetrics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.4->sdmetrics) (2023.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly<6,>=5.10.0->sdmetrics) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly<6,>=5.10.0->sdmetrics) (23.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=0.24->sdmetrics) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2,>=0.24->sdmetrics) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdmetrics) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdmetrics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdmetrics) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdmetrics) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdmetrics) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4,>=3.6.0->copulas<0.10,>=0.9.0->sdmetrics) (3.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.3.4->sdmetrics) (1.16.0)

# %% [markdown]
# ## Parametri

# %% [markdown]
# 1.   Alpha (for LeakyReLU):
# > * alpha is the slope of the negative part of the LeakyReLU activation function. It helps introduce a small, non-zero slope to the activation function for negative input values, preventing the neuron from being completely inactive.
# > * A common value for alpha is in the range of 0.01 to 0.3. You can experiment with different values to see what works best for your specific dataset and model.
#
# 2.   Momentum (for Batch Normalization):
# > * momentum is a parameter used in the update of the moving averages in batch normalization. It controls the contribution of the previous running mean and variance to the new estimates.
# > * Common values for momentum are between 0.9 and 0.999. Higher values give more weight to the new batch, and lower values give more weight to the history.
#
# 3.   Dropout Rate (for Discriminator):
# > * rate is the dropout rate, which represents the fraction of input units to drop during training.
# > * A common value for rate is between 0.3 and 0.5. This means dropping 30% to 50% of the input units during training.

# %%
alpha_leakyRelu = 0.15 #@param
momentumBN = 0.8 #@param
dropoutRate = 0.1 #@param
neuroni = 128 #@param

# %%
#generator & discriminator parameters

batch_size = 2048 #@param
lr_d=0.0001 #@param
lr_g=0.0003 #@param

beta=0.5  #@param
noise_dim = 16  #@param

#--------------------------------
data_dim=35 #numeroFeatures
label_dim=6
#-------------------------------

#training parameters
epochs = 6000 #@param
n_eval = 50 #@param

# %% [markdown]
# ### Plot GAN

# %% [markdown]
# FONTE: https://machinelearningmastery.com/practical-guide-to-gan-failure-modes/

# %%
def plot_historyBIG(d_hist, g_hist, a1_hist, a2_hist):
    # create a larger figure
    fig, axs = plt.subplots(2, 1, figsize=(10, 8))

    # plot loss
    axs[0].plot(d_hist, label='d-loss')
    axs[0].plot(g_hist, label='g-loss')
    axs[0].legend()

    # plot discriminator accuracy
    axs[1].plot(a1_hist, label='acc-real')
    axs[1].plot(a2_hist, label='acc-fake')
    axs[1].legend()

    plt.show()

# %% [markdown]
# ## **Architettura Modello**
# * Fonte codice base: https://github.com/CameronSwart/GAN-IDS

# %% [markdown]
# #### Vanilla GAN

# %%
def gan_system():

    def build_generator(data_dim, noise_dim):
        model = Sequential(name="Generatore")
        model.add(Dense(neuroni, activation=LeakyReLU(alpha_leakyRelu), kernel_initializer="he_uniform", input_dim=noise_dim))
        model.add(BatchNormalization(momentum=momentumBN))
        model.add(Dense(neuroni*2, activation=LeakyReLU(alpha_leakyRelu), kernel_initializer="he_uniform"))
        model.add(BatchNormalization(momentum=momentumBN))
        model.add(Dense(neuroni*4, activation=LeakyReLU(alpha_leakyRelu), kernel_initializer="he_uniform"))
        model.add(BatchNormalization(momentum=momentumBN))
        model.add(Dense(data_dim, activation="sigmoid")) # Use sigmoid activation in the output layer to constrain values to [0, 1]
        return model

    generator = build_generator(data_dim, noise_dim)

    optimizerD = tf.keras.optimizers.Adam(learning_rate=lr_d)

    def build_discriminator(data_dim):
        model = Sequential(name="Discriminatore")
        model.add(Dense(neuroni*4, activation=LeakyReLU(alpha_leakyRelu), kernel_initializer="he_uniform", input_dim=data_dim))
        model.add(Dropout(dropoutRate))
        model.add(Dense(neuroni*2, activation=LeakyReLU(alpha_leakyRelu), kernel_initializer="he_uniform"))
        model.add(Dropout(dropoutRate))
        model.add(Dense(neuroni, activation=LeakyReLU(alpha_leakyRelu), kernel_initializer="he_uniform"))
        model.add(Dropout(dropoutRate)) #prima non c'era!!!
        model.add(Dense(1, activation="sigmoid"))
        model.compile(loss="binary_crossentropy", optimizer=optimizerD, metrics=["accuracy"])
        return model

    discriminator = build_discriminator(data_dim)

    optimizerGAN = tf.keras.optimizers.Adam(learning_rate=lr_g)

    def build_gan(generator, discriminator):
        # make weights in the discriminator not trainable
        discriminator.trainable = False
        # connect generator and dicriminator
        model = Sequential(name="GAN")
        model.add(generator)
        model.add(discriminator)
        model.compile(loss = "binary_crossentropy", optimizer = optimizerGAN)
        return model


    gan = build_gan(generator, discriminator)

    return gan, generator, discriminator



def train(gan, generator, discriminator, data, noise_dim, n_epochs, n_batch, n_eval):
    #Half batch size for updateting discriminator
    half_batch = int(n_batch / 2)

    d_hist, g_hist, a1_hist, a2_hist = list(), list(), list(), list()

    #generate class labels for fake = 0 and real = 1
    valid = np.ones((half_batch, 1))
    fake = np.zeros((half_batch, 1))
    y_gan = np.ones((n_batch, 1))

    np.random.seed(3) # used for retestability

    #training loop
    for j in range(n_epochs):
        #select random batch from the real numerical data
        idx = np.random.randint(0, data.shape[0], half_batch)
        real_data = data[idx]

        #Generate noise from a Gaussian (normal) distribution
        noise = np.random.normal(0, 1, (half_batch, noise_dim))
        fake_data = generator.predict(noise)

        #train the discriminator and return losses
        d_loss_real, d_acc1 = discriminator.train_on_batch(real_data, valid)
        d_loss_fake, d_acc2 = discriminator.train_on_batch(fake_data, fake)
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        #generate noise for generator input and  train the generator (to have the discriminator label samples as valid)
        noise = np.random.normal(0, 1, (n_batch, noise_dim))
        g_loss = gan.train_on_batch(noise, y_gan)

        d_hist.append(d_loss)
        g_hist.append(g_loss)
        a1_hist.append(d_acc1)
        a2_hist.append(d_acc2)

        #evaluate progress
        if (j+1) % n_eval == 0:
            print('==>> Epoch %d ==> dRealLoss=%.3f, dFakeLoss=%.3f, dTOTLoss=%.3f, gLoss=%.3f, accR=%d, accF=%d' % (j, d_loss_real, d_loss_fake,d_loss, g_loss, int(100*d_acc1), int(100*d_acc2)))

    #plot losses after training
    plot_historyBIG(d_hist, g_hist, a1_hist, a2_hist)

# %%
gan, generator, discriminator = gan_system()

# %% [markdown]
# #### VanillaGAN con label

# %%
def gan_system():

    def build_generator(data_dim, noise_dim, label_dim):
        model = Sequential(name="Generator")
        model.add(Dense(neuroni, activation=LeakyReLU(alpha_leakyRelu), kernel_initializer="he_uniform", input_dim=noise_dim))
        model.add(BatchNormalization(momentum=momentumBN))
        model.add(Dense(neuroni*2, activation=LeakyReLU(alpha_leakyRelu), kernel_initializer="he_uniform"))
        model.add(BatchNormalization(momentum=momentumBN))
        model.add(Dense(neuroni*4, activation=LeakyReLU(alpha_leakyRelu), kernel_initializer="he_uniform"))
        model.add(BatchNormalization(momentum=momentumBN))
        model.add(Dense(data_dim+label_dim, activation="sigmoid"))  # Use sigmoid activation in the output layer to constrain values to [0, 1]
        return model

    generator = build_generator(data_dim, noise_dim, label_dim)

    optimizerD = tf.keras.optimizers.Adam(learning_rate=lr_d)

    def build_discriminator(data_dim, label_dim):
        model = Sequential(name="Discriminator")
        model.add(Dense(neuroni*4, activation=LeakyReLU(alpha_leakyRelu), kernel_initializer="he_uniform", input_dim=data_dim + label_dim))
        model.add(Dropout(dropoutRate))
        model.add(Dense(neuroni*2, activation=LeakyReLU(alpha_leakyRelu), kernel_initializer="he_uniform"))
        model.add(Dropout(dropoutRate))
        model.add(Dense(neuroni, activation=LeakyReLU(alpha_leakyRelu), kernel_initializer="he_uniform"))
        model.add(Dropout(dropoutRate))
        model.add(Dense(1, activation="sigmoid"))
        model.compile(loss="binary_crossentropy", optimizer=optimizerD, metrics=["accuracy"])
        return model

    discriminator = build_discriminator(data_dim, label_dim)

    optimizerGAN = tf.keras.optimizers.Adam(learning_rate=lr_g)

    def build_gan(generator, discriminator):
        # Make weights in the discriminator not trainable
        discriminator.trainable = False
        # Connect generator and discriminator
        model = Sequential(name="GAN")
        model.add(generator)
        model.add(discriminator)
        model.compile(loss="binary_crossentropy", optimizer=optimizerGAN)
        return model

    gan = build_gan(generator, discriminator)

    return gan, generator, discriminator


def train(gan, generator, discriminator, data, labels, noise_dim, n_epochs, n_batch, n_eval):
    # Half batch size for updating the discriminator
    half_batch = int(n_batch / 2)

    d_hist, g_hist, a1_hist, a2_hist = list(), list(), list(), list()

    # Generate class labels for fake = 0 and real = 1
    valid = np.ones((half_batch, 1))
    fake = np.zeros((half_batch, 1))
    y_gan = np.ones((n_batch, 1))

    np.random.seed(3)  # Used for retestability

    # Training loop
    for j in range(n_epochs):
        # Select a random batch from the real numerical data
        idx = np.random.randint(0, data.shape[0], half_batch)
        real_data = data[idx]
        real_labels = labels[idx]

        # Generate noise from a Gaussian (normal) distribution
        noise = np.random.normal(0, 1, (half_batch, noise_dim))
        fake_data = generator.predict([noise, real_labels])

        # Train the discriminator and return losses
        d_loss_real, d_acc1 = discriminator.train_on_batch(np.concatenate([real_data, real_labels], axis=1), valid)
        d_loss_fake, d_acc2 = discriminator.train_on_batch(np.concatenate([fake_data, real_labels], axis=1), fake)
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

        # Generate noise for the generator input and train the generator (to have the discriminator label samples as valid)
        noise = np.random.normal(0, 1, (n_batch, noise_dim))
        g_loss = gan.train_on_batch([noise, real_labels], y_gan)

        d_hist.append(d_loss)
        g_hist.append(g_loss)
        a1_hist.append(d_acc1)
        a2_hist.append(d_acc2)

        # Evaluate progress
        if (j + 1) % n_eval == 0:
            print('==>> Epoch %d ==> dRealLoss=%.3f, dFakeLoss=%.3f, dTOTLoss=%.3f, gLoss=%.3f, accR=%d, accF=%d' %
                  (j, d_loss_real, d_loss_fake, d_loss, g_loss, int(100 * d_acc1), int(100 * d_acc2)))

    # Plot losses after training
    plot_historyBIG(d_hist, g_hist, a1_hist, a2_hist)

# %%
gan, generator, discriminator = gan_system()

# %% [markdown]
# #### Summary Architettura

# %%
gan.summary()
# Out:
# Model: "GAN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Generatore (Sequential)     (None, 41)                191401
#
#  Discriminatore (Sequential  (None, 6)                 186502
#  )
#
# =================================================================
# Total params: 377903 (1.44 MB)
# Trainable params: 189609 (740.66 KB)
# Non-trainable params: 188294 (735.52 KB)
# _________________________________________________________________

# %%
generator.summary()
# Out:
# Model: "Generatore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 128)               2176
#
#  batch_normalization_3 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_9 (Dense)             (None, 256)               33024
#
#  batch_normalization_4 (Bat  (None, 256)               1024
#  chNormalization)
#
#  dense_10 (Dense)            (None, 512)               131584
#
#  batch_normalization_5 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dense_11 (Dense)            (None, 41)                21033
#
# =================================================================
# Total params: 191401 (747.66 KB)
# Trainable params: 189609 (740.66 KB)
# Non-trainable params: 1792 (7.00 KB)
# _________________________________________________________________

# %%
discriminator.summary()
# Out:
# Model: "Discriminatore"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 512)               21504
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_13 (Dense)            (None, 256)               131328
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_14 (Dense)            (None, 128)               32896
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_15 (Dense)            (None, 6)                 774
#
# =================================================================
# Total params: 186502 (728.52 KB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 186502 (728.52 KB)
# _________________________________________________________________

# %% [markdown]
# ## **Training & Generazione**

# %%
train(gan, generator, discriminator, data, label_data, noise_dim, epochs, batch_size, n_eval)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-9298e1cbae61> in <cell line: 1>()
# ----> 1 train(gan, generator, discriminator, data, label_data, noise_dim, epochs, batch_size, n_eval)
#
# <ipython-input-23-3bd912de7f44> in train(gan, generator, discriminator, data, labels, noise_dim, n_epochs, n_batch, n_eval)
#      69         # Generate noise from a Gaussian (normal) distribution
#      70         noise = np.random.normal(0, 1, (half_batch, noise_dim))
# ---> 71         fake_data = generator.predict([noise, real_labels])
#      72
#      73         # Train the discriminator and return losses
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__predict_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2440, in predict_function  *
#         return step_function(self, iterator)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2425, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2413, in run_step  **
#         outputs = model.predict_step(data)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2381, in predict_step
#         return self(x, training=False)
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/input_spec.py", line 219, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Layer "Generator" expects 1 input(s), but it received 2 input tensors. Inputs received: [<tf.Tensor 'IteratorGetNext:0' shape=(32, 16) dtype=float32>, <tf.Tensor 'IteratorGetNext:1' shape=(32, 6) dtype=float32>]

# %%
train(gan, generator, discriminator, merged_data, noise_dim,
      epochs, batch_size, n_eval)
# Out:
# Output streaming troncato alle ultime 5000 righe.
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 1099 ==> dRealLoss=0.639, dFakeLoss=0.629, dTOTLoss=0.634, gLoss=0.791, accR=45, accF=69
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 1149 ==> dRealLoss=0.645, dFakeLoss=0.632, dTOTLoss=0.639, gLoss=0.787, accR=45, accF=68
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 1199 ==> dRealLoss=0.638, dFakeLoss=0.640, dTOTLoss=0.639, gLoss=0.778, accR=46, accF=66
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 1249 ==> dRealLoss=0.593, dFakeLoss=0.588, dTOTLoss=0.590, gLoss=0.877, accR=53, accF=74
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 1299 ==> dRealLoss=0.574, dFakeLoss=0.657, dTOTLoss=0.616, gLoss=0.874, accR=65, accF=58
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 1349 ==> dRealLoss=0.646, dFakeLoss=0.671, dTOTLoss=0.658, gLoss=0.785, accR=58, accF=57
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 1399 ==> dRealLoss=0.649, dFakeLoss=0.652, dTOTLoss=0.651, gLoss=0.789, accR=53, accF=61
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 1449 ==> dRealLoss=0.673, dFakeLoss=0.690, dTOTLoss=0.681, gLoss=0.752, accR=52, accF=62
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 1499 ==> dRealLoss=0.678, dFakeLoss=0.655, dTOTLoss=0.667, gLoss=0.825, accR=52, accF=63
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 1549 ==> dRealLoss=0.691, dFakeLoss=0.647, dTOTLoss=0.669, gLoss=0.790, accR=47, accF=68
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 1599 ==> dRealLoss=0.655, dFakeLoss=0.673, dTOTLoss=0.664, gLoss=0.754, accR=53, accF=60
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 1649 ==> dRealLoss=0.680, dFakeLoss=0.665, dTOTLoss=0.673, gLoss=0.760, accR=48, accF=62
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 1699 ==> dRealLoss=0.672, dFakeLoss=0.665, dTOTLoss=0.668, gLoss=0.766, accR=47, accF=63
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 1749 ==> dRealLoss=0.680, dFakeLoss=0.649, dTOTLoss=0.665, gLoss=0.778, accR=45, accF=66
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 1799 ==> dRealLoss=0.691, dFakeLoss=0.709, dTOTLoss=0.700, gLoss=0.728, accR=47, accF=60
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 1849 ==> dRealLoss=0.663, dFakeLoss=0.680, dTOTLoss=0.672, gLoss=0.749, accR=48, accF=61
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 1899 ==> dRealLoss=0.623, dFakeLoss=0.696, dTOTLoss=0.660, gLoss=0.715, accR=68, accF=51
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 1949 ==> dRealLoss=0.682, dFakeLoss=0.660, dTOTLoss=0.671, gLoss=0.765, accR=45, accF=65
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ...
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 5749 ==> dRealLoss=0.680, dFakeLoss=0.604, dTOTLoss=0.642, gLoss=0.806, accR=36, accF=81
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 5799 ==> dRealLoss=0.671, dFakeLoss=0.628, dTOTLoss=0.649, gLoss=0.785, accR=33, accF=78
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 5849 ==> dRealLoss=0.674, dFakeLoss=0.616, dTOTLoss=0.645, gLoss=0.800, accR=40, accF=79
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 5899 ==> dRealLoss=0.663, dFakeLoss=0.649, dTOTLoss=0.656, gLoss=0.768, accR=36, accF=75
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 5949 ==> dRealLoss=0.656, dFakeLoss=0.611, dTOTLoss=0.633, gLoss=0.806, accR=42, accF=79
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 2ms/step
# 32/32 [==============================] - 0s 1ms/step
# 32/32 [==============================] - 0s 1ms/step
# ==>> Epoch 5999 ==> dRealLoss=0.674, dFakeLoss=0.631, dTOTLoss=0.652, gLoss=0.787, accR=38, accF=77

# %%
np.random.seed(3) # used for retestability

num_rows_gen = df.shape[0] #quante righe verranno generate
#num_rows_gen = 1000 #quante righe verranno generate

#Generate noise from a Gaussian (normal) distribution
noise = np.random.normal(0, 1, (num_rows_gen, noise_dim))
X = generator.predict(noise)
# Out:
# 45933/45933 [==============================] - 63s 1ms/step

# %%
gen_samples = pd.DataFrame(X, columns=df.columns)

# %% [markdown]
# #### Salvo csv

# %%
#SALVO CSV data gen
#gen_samples.to_csv(r'drive/My Drive/Colab Notebooks/progettoTesi/Dataset2017/GANgen/Valutazione/tentativo2/genBotnet.csv', index = False)
#gen_samples.to_csv(r'drive/My Drive/Colab Notebooks/progettoTesi/Dataset2017/GANgen/Valutazione/tentativo2/genBruteforce.csv', index = False)
#gen_samples.to_csv(r'drive/My Drive/Colab Notebooks/progettoTesi/Dataset2017/GANgen/Valutazione/tentativo2/genDDoS.csv', index = False)
#gen_samples.to_csv(r'drive/My Drive/Colab Notebooks/progettoTesi/Dataset2017/GANgen/Valutazione/tentativo2/genDoS.csv', index = False)
#gen_samples.to_csv(r'drive/My Drive/Colab Notebooks/progettoTesi/Dataset2017/GANgen/Valutazione/tentativo2/genPortscan.csv', index = False)
#gen_samples.to_csv(r'drive/My Drive/Colab Notebooks/progettoTesi/Dataset2017/GANgen/Valutazione/tentativo2/genBenign.csv', index = False)

# %% [markdown]
# #### Preparo x valutazione Quant&Qualit

# %%
print(df.shape)
print(gen_samples.shape)
# Out:
# (1469838, 41)
# (1469838, 41)

# %%
df.head()
# Out:
#             FlowDuration     BwdPacketLengthStd                DstPort  \
# 0 0.12336963641757420218 0.01609175409250790043 0.00679088647774260014
# 1 0.10006393583493169985 0.45023456904328618133 0.00122083352408849997
# 2 0.02394830893204100142 0.12327550179217569570 0.00676036563964039963
# 3 0.08757281885598709736 0.32622330025341017556 0.00122083352408849997
# 4 0.07373842684346060272 0.11576662688246899813 0.00676036563964039963
#
#    TotalLengthofFwdPacket             FlowIATMax   PacketLengthVariance  \
# 0  0.00057947583310719996 0.12170791145253699594 0.01307735349845779924
# 1  0.00000155397112659488 0.09944774544250239989 0.20083179857744729024
# 2  0.00004320039731933765 0.01922706761999979849 0.01452055111006299998
# 3  0.00000155397112659488 0.08290614210861499411 0.13631339619087889936
# 4  0.00013713795192189999 0.04115367455731189922 0.04065396673467199656
#
#          PacketLengthStd     BwdPacketLengthMax          FlowPackets/s  \
# 0 0.11435625692745379767 0.01331285202252940024 0.00000100488187634421
# 1 0.44814260964278690436 0.37378392217101891193 0.00000035254699793876
# 2 0.12050124941287139457 0.11607782898105470371 0.00000242746764235071
# 3 0.36920644115572920363 0.29902713773681510734 0.00000040402185551578
# 4 0.20162828852785530387 0.22242703533026109142 0.00000696074463230835
#
#             RSTFlagCount  ...        BwdHeaderLength            FwdIATTotal  \
# 0 0.01052631578947360071  ... 0.50712059165087708390 0.12336959372282650660
# 1 0.00526315789473680035  ... 0.50235315689750015267 0.10006394333439899702
# 2 0.00000000000000000000  ... 0.50351445510665615579 0.02394831706580519831
# 3 0.00526315789473680035  ... 0.50265876168938328217 0.08757282645954710121
# 4 0.00000000000000000000  ... 0.54984414155613969832 0.07345465122424410520
#
#            FwdSegSizeMin        FWDInitWinBytes               L_BENIGN  \
# 0 0.45454545454545458583 0.12500190737773708705 1.00000000000000000000
# 1 0.45454545454545458583 0.12500190737773708705 0.00000000000000000000
# 2 0.45454545454545458583 0.12500190737773708705 1.00000000000000000000
# 3 0.45454545454545458583 0.12500190737773708705 0.00000000000000000000
# 4 0.72727272727272729291 0.44556343938353548673 1.00000000000000000000
#
#    L_Infiltration_Portscan                 L_DDoS                  L_DoS  \
# 0   0.00000000000000000000 0.00000000000000000000 0.00000000000000000000
# 1   0.00000000000000000000 1.00000000000000000000 0.00000000000000000000
# 2   0.00000000000000000000 0.00000000000000000000 0.00000000000000000000
# 3   0.00000000000000000000 1.00000000000000000000 0.00000000000000000000
# 4   0.00000000000000000000 0.00000000000000000000 0.00000000000000000000
#
#             L_BruteForce               L_Botnet
# 0 0.00000000000000000000 0.00000000000000000000
# 1 0.00000000000000000000 0.00000000000000000000
# 2 0.00000000000000000000 0.00000000000000000000
# 3 0.00000000000000000000 0.00000000000000000000
# 4 0.00000000000000000000 0.00000000000000000000
#
# [5 rows x 41 columns]

# %%
gen_samples.head()
# Out:
#             FlowDuration     BwdPacketLengthStd                DstPort  \
# 0 0.00000000000000090336 0.00000000004692570638 0.00000003626821154512
# 1 0.97928404808044433594 0.07828385382890701294 0.00049520138418301940
# 2 0.00001760106351866852 0.49620619416236877441 0.00000089934303559858
# 3 0.07841500639915466309 0.06081777811050415039 0.00103865086566656828
# 4 0.00003976997322752140 0.00016867944214027375 0.00011138616537209600
#
#    TotalLengthofFwdPacket             FlowIATMax   PacketLengthVariance  \
# 0  0.00000001386864045827 0.00000000042005826595 0.00000000713298931032
# 1  0.00000507260801896336 0.15335850417613983154 0.00231477385386824608
# 2  0.00000499780526297400 0.00208548386581242085 0.24707148969173431396
# 3  0.00000311738017444441 0.01290796417742967606 0.00095119251636788249
# 4  0.00000837066181702539 0.00011529659241205081 0.00002401471465418581
#
#          PacketLengthStd     BwdPacketLengthMax          FlowPackets/s  \
# 0 0.00000000010848114768 0.00000000080206574715 0.00002470555955369491
# 1 0.06884586811065673828 0.05908129364252090454 0.00002171167943743058
# 2 0.54241210222244262695 0.42705178260803222656 0.00000000006055519280
# 3 0.04495962336659431458 0.04079557582736015320 0.00011362940131220967
# 4 0.00375633104704320431 0.00202219653874635696 0.00318530597724020481
#
#             RSTFlagCount  ...        BwdHeaderLength            FwdIATTotal  \
# 0 0.00000338467384608521  ... 0.49925047159194946289 0.00000000000000080734
# 1 0.00005555447569349781  ... 0.52518838644027709961 0.97784912586212158203
# 2 0.00000003599104658747  ... 0.42199003696441650391 0.00014333105355035514
# 3 0.00023422155936714262  ... 0.47645890712738037109 0.08012066781520843506
# 4 0.00003543067577993497  ... 0.50965332984924316406 0.00002456909714965150
#
#            FwdSegSizeMin        FWDInitWinBytes               L_BENIGN  \
# 0 0.51965796947479248047 0.00009600001794751734 0.00000000000000000000
# 1 0.56997960805892944336 0.16941508650779724121 1.00000000000000000000
# 2 0.41559380292892456055 0.38128650188446044922 0.00000000040608047480
# 3 0.72223907709121704102 0.20395645499229431152 1.00000000000000000000
# 4 0.17727608978748321533 0.00002768218473647721 1.00000000000000000000
#
#    L_Infiltration_Portscan                 L_DDoS                  L_DoS  \
# 0   1.00000000000000000000 0.00000022340984173752 0.00000000229505414673
# 1   0.00000000061984511968 0.00000177028277903446 0.00000000001237419455
# 2   0.00000000023740739930 0.99998843669891357422 0.00000000043729161958
# 3   0.00000000028360072624 0.00000033839529578472 0.00000002350014050023
# 4   0.00000000013542736377 0.00000104548314538988 0.00012543878983706236
#
#             L_BruteForce               L_Botnet
# 0 0.00000000007766577659 0.00000000978873337942
# 1 0.00004776948844664730 0.00000789311525295489
# 2 0.00000863634795678081 0.00000841530891193543
# 3 0.00003992177880718373 0.00000624062704446260
# 4 0.00001119095486501465 0.00000584634881306556
#
# [5 rows x 41 columns]

# %% [markdown]
# #Valutazione

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 6))
sns.heatmap(df.corr(), annot=False, ax=ax[0], cmap="Blues")
sns.heatmap(gen_samples.corr(), annot=False, ax=ax[1], cmap="Blues")
ax[0].set_title("Dati reali")
ax[1].set_title("Dati generati")
# Out:
# Text(0.5, 1.0, 'Dati generati')

# %%
real_data = df.to_numpy()
generated_data = gen_samples.to_numpy()

# %%
from scipy.stats import wasserstein_distance

real_flat = real_data.flatten()
generated_flat = generated_data.flatten()
#provides a global measure of dissimilarity between the real and generated data distributions
w_distance = wasserstein_distance(real_flat, generated_flat)

print('Wasserstein Distance real vs gen:', w_distance)
# Out:
# Wasserstein Distance real vs gen: 0.01164552543974912

# %%
real_col = df['FlowDuration'].to_numpy()
gen_col = gen_samples['FlowDuration'].to_numpy()

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(real_col, gen_col)
print(f"Mean Squared Error: {mse}")
# Out:
# Mean Squared Error: 0.13456429861134225

# %% [markdown]
# * ***KLDivergence*** ==> you can use it to measure the difference between the distribution of your real data and the distribution of the generated data ==> =0

# %%
kl = tf.keras.metrics.KLDivergence()
print("KLDivergence:", kl(real_col, gen_col).numpy())
# Out:
# KLDivergence: 1110289.4

# %%
w_dist_feature = wasserstein_distance(real_col, gen_col)
print("Wasserstein Distance:", w_dist_feature)
# Out:
# Wasserstein Distance: 0.010147861335900623

# %%
from scipy import stats
stats.ks_2samp(real_col, gen_col)
# Out:
# KstestResult(statistic=0.19316006253750412, pvalue=0.0, statistic_location=0.00019270811753813177, statistic_sign=-1)

# %%
# Choose the column you want to check
# 0 = FlowDuration
# 1 = BwdPacketLengthStd
# 2 = DstPort
# 3 = TotalLenghtofFwdPacket
# 4 = FlowIATMax
# 5 = PacketLengthVariance

# 12 = BwdPacketLengthMean

# %%
column_to_compare = 0
# Extract the selected column for each array
real_column = real_data[:, column_to_compare]
generated_column = generated_data[:, column_to_compare]

# Plot the KDE for both distributions
sns.kdeplot(real_column, label='Dati reali', fill=True)
sns.kdeplot(generated_column, label='Dati generati', fill=True)

# Add labels and legend
plt.title(f'Confronto distribuzioni della feature: {df.columns[column_to_compare]}')
plt.xlabel('Valori')
plt.ylabel('Densità')
plt.legend(loc='best') #upper left
#salva in Drive
#images_dir = '/content/drive/MyDrive/Colab Notebooks/progettoTesi/grafici_pdf'
#plt.savefig(f"{images_dir}/distributionFeatureFlowDuration_genGAN_t2.pdf", dpi=200, format='pdf') ###!!!!!!!!!!!!!! CAMBIARE TENTATIVI CON N°
plt.show()

# %% [markdown]
# #### Scatter plot di feature in relazione & interessanti

# %%
alphaTrasparenza = 0.2
#0 = trasparente & 1=pieno

# %%
fig, axs = plt.subplots(2, 3, figsize=(18, 10))


axs[0, 0].scatter(df.iloc[:, 0], df.iloc[:, 32], label='Dati Reali')
axs[0, 0].scatter(gen_samples.iloc[:, 0], gen_samples.iloc[:, 32], label='Dati Generati', c='orange', alpha=alphaTrasparenza)
axs[0, 0].set_title("Feature 0 vs. Feature 32")
axs[0, 0].legend()


axs[0, 1].scatter(df.iloc[:, 1], df.iloc[:, 29], label='Dati Reali')
axs[0, 1].scatter(gen_samples.iloc[:, 1], gen_samples.iloc[:, 29], label='Dati Generati', c='orange', alpha=alphaTrasparenza)
axs[0, 1].set_title("Feature 1 vs. Feature 29")
axs[0, 1].legend()

axs[0, 2].scatter(df.iloc[:, 15], df.iloc[:, 26], label='Dati Reali')
axs[0, 2].scatter(gen_samples.iloc[:, 15], gen_samples.iloc[:, 26], label='Dati Generati', c='orange', alpha=alphaTrasparenza)
axs[0, 2].set_title("Feature 15 vs. Feature 26")
axs[0, 2].legend()

axs[1, 0].scatter(df.iloc[:, 27], df.iloc[:, 32], label='Dati Reali')
axs[1, 0].scatter(gen_samples.iloc[:, 27], gen_samples.iloc[:, 32], label='Dati Generati', c='orange', alpha=alphaTrasparenza)
axs[1, 0].set_title("Feature 27 vs. Feature 32")
axs[1, 0].legend()

axs[1, 1].scatter(df.iloc[:, 26], df.iloc[:, 12], label='Dati Reali')
axs[1, 1].scatter(gen_samples.iloc[:, 26], gen_samples.iloc[:, 12], label='Dati Generati', c='orange', alpha=alphaTrasparenza)
axs[1, 1].set_title("Feature 26 vs. Feature 12")
axs[1, 1].legend()

axs[1, 2].scatter(df.iloc[:, 22], df.iloc[:, 11], label='Dati Reali')
axs[1, 2].scatter(gen_samples.iloc[:, 22], gen_samples.iloc[:, 11], label='Dati Generati', c='orange', alpha=alphaTrasparenza)
axs[1, 2].set_title("Feature 22 vs. Feature 11")
axs[1, 2].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# #Valutazione SDV
# *   https://github.com/sdv-dev/SDV
# *   https://docs.sdv.dev/sdv

# %%
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(df)

# %%
quality_report = evaluate_quality(
    real_data=df,
    synthetic_data=gen_samples,
    metadata=metadata)
# Out:
# Generating report ...
# (1/2) Evaluating Column Shapes: :  88%|████████▊ | 36/41 [04:33<06:35, 79.13s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-2ccb7dba8a1d> in <cell line: 1>()
# ----> 1 quality_report = evaluate_quality(
#       2     real_data=df,
#       3     synthetic_data=gen_samples,
#       4     metadata=metadata)
#
# /usr/local/lib/python3.10/dist-packages/sdv/evaluation/single_table.py in evaluate_quality(real_data, synthetic_data, metadata, verbose)
#      28     """
#      29     quality_report = QualityReport()
# ---> 30     quality_report.generate(real_data, synthetic_data, metadata.to_dict(), verbose)
#      31     return quality_report
#      32
#
# /usr/local/lib/python3.10/dist-packages/sdmetrics/reports/base_report.py in generate(self, real_data, synthetic_data, metadata, verbose)
#     185                 )
#     186
# --> 187             score = self._properties[property_name].get_score(
#     188                 real_data, synthetic_data, metadata, progress_bar=progress_bar
#     189             )
#
# /usr/local/lib/python3.10/dist-packages/sdmetrics/reports/single_table/_properties/base.py in get_score(self, real_data, synthetic_data, metadata, progress_bar)
#      52                 The average score for the property.
#      53         """
# ---> 54         self.details = self._generate_details(real_data, synthetic_data, metadata, progress_bar)
#      55         return self._compute_average()
#      56
#
# /usr/local/lib/python3.10/dist-packages/sdmetrics/reports/single_table/_properties/column_shapes.py in _generate_details(self, real_data, synthetic_data, metadata, progress_bar)
#      46                 if sdtype in self._sdtype_to_metric:
#      47                     metric = self._sdtype_to_metric[sdtype]
# ---> 48                     column_score = metric.compute(
#      49                         real_data[column_name], synthetic_data[column_name]
#      50                     )
#
# /usr/local/lib/python3.10/dist-packages/sdmetrics/single_column/statistical/tv_complement.py in compute(cls, real_data, synthetic_data)
#      51                 'The TVComplement metric must have 1 or more non-null values.')
#      52
# ---> 53         f_obs, f_exp = get_frequencies(real_data, synthetic_data)
#      54         total_variation = 0
#      55         for i in range(len(f_obs)):
#
# /usr/local/lib/python3.10/dist-packages/sdmetrics/utils.py in get_frequencies(real, synthetic)
#      68     for value in real:
#      69         f_obs.append(synthetic[value] / sum(synthetic.values()))  # noqa: PD011
# ---> 70         f_exp.append(real[value] / sum(real.values()))  # noqa: PD011
#      71
#      72     return f_obs, f_exp
#
# KeyboardInterrupt:

# %%
diagnostic_report = run_diagnostic(
    real_data=df,
    synthetic_data=gen_samples,
    metadata=metadata)
